# %% [markdown]
# # Ejercicio 3 - Adrián José Zapater Reig

# %%
 ! mkdir mongodb-cluster-docker-compose
# Out:
# mkdir: mongodb-cluster-docker-compose: File exists

# %%
! git clone https://github.com/mhaut/mongodb-cluster-docker-compose mongodb-cluster-docker-compose
# Out:
# fatal: destination path 'mongodb-cluster-docker-compose' already exists and is not an empty directory.

# %% [markdown]
# ## Step 1

# %%
! docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml up -d
# Out:
# Creating network "mongodb-cluster-docker-compose_default" with the default driver
# Creating rydell-shard-03-node-b ...
# Creating rydell-shard-02-node-b ...
# Creating rydell-shard-01-node-c ...
# Creating rydell-shard-01-node-b ...
# Creating rydell-shard-02-node-c ...
# Creating rydell-shard-03-node-c ...
# Creating rydell-router-01       ...
# ting rydell-shard-02-node-c ... doneCreating rydell-shard-02-node-a ...
# Creating rydell-router-02       ... mdone
# ting rydell-shard-01-node-c ... doneCreating rydell-shard-03-node-a ...
# Creating rydell-shard-01-node-a ...
# ting rydell-shard-01-node-a ... doneCreating rydell-mongo-config-01 ...
# ting rydell-mongo-config-01 ... doneCreating rydell-mongo-config-02 ...
# ting rydell-mongo-config-02 ... doneCreating rydell-mongo-config-03 ...
# ting rydell-mongo-config-03 ... done

# %% [markdown]
# ## Step 2

# %%
! docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec configsvr01 sh -c "mongo < /scripts/init-configserver.js"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("dc1da413-bbce-460f-8633-6db87a0c1dd8") }
# MongoDB server version: 4.0.18
# {
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172694, 1),
# 	"$gleStats" : {
# 		"lastOpTime" : Timestamp(1618172694, 1),
# 		"electionId" : ObjectId("000000000000000000000000")
# 	},
# 	"lastCommittedOpTime" : Timestamp(0, 0),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172694, 1),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %%
! docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec shard01-a sh -c "mongo < /scripts/init-shard01.js"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("c19637e7-ec0e-4bbb-ae30-eddbdf1aa6d4") }
# MongoDB server version: 4.0.18
# {
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172697, 1),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172697, 1),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %%
! docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec shard02-a sh -c "mongo < /scripts/init-shard02.js"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("4f66958a-aa2a-4f38-80b4-b9eee65d3577") }
# MongoDB server version: 4.0.18
# {
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172702, 1),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172702, 1),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %%
! docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec shard03-a sh -c "mongo < /scripts/init-shard03.js"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("4bda382a-a322-412e-b3c4-4026f8cf04e3") }
# MongoDB server version: 4.0.18
# {
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172706, 1),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172706, 1),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %% [markdown]
# ## Step 3

# %%
# Esperamos 15 segundos a que los shards y config servers elijan al nodo primario.
! sleep 15

# %%
! docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec router01 sh -c "mongo < /scripts/init-router.js"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("60b34f99-a833-4dcc-bf78-5c8fa579ad8e") }
# MongoDB server version: 4.0.18
# {
# 	"shardAdded" : "rs-shard-01",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172751, 5),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172751, 5),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-01",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172751, 5),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172751, 5),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-01",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172751, 5),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172751, 5),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-02",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172752, 3),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172752, 3),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-02",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172752, 3),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172752, 3),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-02",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172752, 3),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172752, 3),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-03",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172752, 8),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172752, 8),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-03",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172752, 8),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172752, 8),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# {
# 	"shardAdded" : "rs-shard-03",
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618172752, 8),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618172752, 8),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %% [markdown]
# ## Step 4

# %% [markdown]
# #### OJO!:
# Ejecutar en consola a parte o el notebook se quedará bloqueado por necesitar interacción del usuario.

# %% [markdown]
# #### Command 1:
# docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec router01 mongo --port 27017

# %% [raw]
# ❯ docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec router01 mongo --port 27017
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("574d07fb-1a4f-4db0-8229-28da1875525f") }
# MongoDB server version: 4.0.18
# Welcome to the MongoDB shell.
# For interactive help, type "help".
# For more comprehensive documentation, see
# 	http://docs.mongodb.org/
# Questions? Try the support group
# 	http://groups.google.com/group/mongodb-user
# Server has startup warnings:
# 2021-04-11T20:22:21.619+0000 I CONTROL  [main]
# 2021-04-11T20:22:21.619+0000 I CONTROL  [main] ** WARNING: Access control is not enabled for the database.
# 2021-04-11T20:22:21.619+0000 I CONTROL  [main] **          Read and write access to data and configuration is unrestricted.
# 2021-04-11T20:22:21.619+0000 I CONTROL  [main]

# %% [markdown]
# #### Command 2:
#
# // Enable sharding for database `MyDatabase` <br/>
# sh.enableSharding("MyDatabase")

# %% [raw]
# mongos> sh.enableSharding("MyDatabase")
# {
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618173068, 5),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618173068, 5),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# mongos>

# %% [markdown]
# #### Command 3:
# // Setup shardingKey for collection `MyCollection`** <br/>
# db.adminCommand( { shardCollection: "MyDatabase.MyCollection", key: { supplierId: "hashed" } } )

# %% [raw]
# mongos> db.adminCommand( { shardCollection: "MyDatabase.MyCollection", key: { supplierId: "hashed" } } )
# {
# 	"collectionsharded" : "MyDatabase.MyCollection",
# 	"collectionUUID" : UUID("664e28b2-a64b-4e2e-bac6-ee357d5ba336"),
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618173108, 51),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618173108, 51),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# mongos>

# %% [markdown]
# ## Verify installation:

# %% [markdown]
# ### Verify the status of the sharded cluster

# %% [markdown]
# sh.status()

# %% [raw]
# mongos> sh.status()
# --- Sharding Status ---
#   sharding version: {
#         "_id" : 1,
#         "minCompatibleVersion" : 5,
#         "currentVersion" : 6,
#         "clusterId" : ObjectId("5eac5a44aa11a78e5e92cecf")
#   }
#   shards:
#         {  "_id" : "rs-shard-01",  "host" : "rs-shard-01/shard01-a:27017,shard01-b:27017,shard01-c:27017",  "state" : 1 }
#         {  "_id" : "rs-shard-02",  "host" : "rs-shard-02/shard02-a:27017,shard02-b:27017,shard02-c:27017",  "state" : 1 }
#         {  "_id" : "rs-shard-03",  "host" : "rs-shard-03/shard03-a:27017,shard03-b:27017,shard03-c:27017",  "state" : 1 }
#   active mongoses:
#         "4.0.18" : 2
#   autosplit:
#         Currently enabled: yes
#   balancer:
#         Currently enabled:  yes
#         Currently running:  no
#         Failed balancer rounds in last 5 attempts:  0
#         Migration Results for the last 24 hours:
#                 No recent migrations
#   databases:
#     {  "_id" : "MyDatabase",  "primary" : "rs-shard-02",  "partitioned" : true,  "version" : {  "uuid" : UUID("b6f1170f-b95f-4726-893a-4d6e9e98f7ec"),  "lastMod" : 1 } }
#                 MyDatabase.MyCollection
#                         shard key: { "supplierId" : "hashed" }
#                         unique: false
#                         balancing: true
#                         chunks:
#                                 rs-shard-01     2
#                                 rs-shard-02     2
#                                 rs-shard-03     2
#                         { "supplierId" : { "$minKey" : 1 } } -->> { "supplierId" : NumberLong("-6148914691236517204") } on : rs-shard-01 Timestamp(1, 0)
#                         { "supplierId" : NumberLong("-6148914691236517204") } -->> { "supplierId" : NumberLong("-3074457345618258602") } on : rs-shard-01 Timestamp(1, 1)
#                         { "supplierId" : NumberLong("-3074457345618258602") } -->> { "supplierId" : NumberLong(0) } on : rs-shard-02 Timestamp(1, 2)
#                         { "supplierId" : NumberLong(0) } -->> { "supplierId" : NumberLong("3074457345618258602") } on : rs-shard-02 Timestamp(1, 3)
#                         { "supplierId" : NumberLong("3074457345618258602") } -->> { "supplierId" : NumberLong("6148914691236517204") } on : rs-shard-03 Timestamp(1, 4)
#                         { "supplierId" : NumberLong("6148914691236517204") } -->> { "supplierId" : { "$maxKey" : 1 } } on : rs-shard-03 Timestamp(1, 5)
#         {  "_id" : "config",  "primary" : "config",  "partitioned" : true }
#                 config.system.sessions
#                         shard key: { "_id" : 1 }
#                         unique: false
#                         balancing: true
#                         chunks:
#                                 rs-shard-01     1
#                         { "_id" : { "$minKey" : 1 } } -->> { "_id" : { "$maxKey" : 1 } } on : rs-shard-01 Timestamp(1, 0)
#
# mongos>

# %% [markdown]
# ### Verify status of replica set for each shard

# %%
! docker exec -it rydell-shard-01-node-a bash -c "echo 'rs.status()' | mongo --port 27017"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("f5c3154a-6cd5-4b1d-8351-65e58b93e330") }
# MongoDB server version: 4.0.18
# {
# 	"set" : "rs-shard-01",
# 	"date" : ISODate("2020-05-01T17:38:29.465Z"),
# 	"myState" : 1,
# 	"term" : NumberLong(1),
# 	"syncingTo" : "",
# 	"syncSourceHost" : "",
# 	"syncSourceId" : -1,
# 	"heartbeatIntervalMillis" : NumberLong(2000),
# 	"optimes" : {
# 		"lastCommittedOpTime" : {
# 			"ts" : Timestamp(1588354709, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"readConcernMajorityOpTime" : {
# 			"ts" : Timestamp(1588354709, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"appliedOpTime" : {
# 			"ts" : Timestamp(1588354709, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"durableOpTime" : {
# 			"ts" : Timestamp(1588354709, 1),
# 			"t" : NumberLong(1)
# 		}
# 	},
# 	"lastStableCheckpointTimestamp" : Timestamp(1588354689, 1),
# 	"electionCandidateMetrics" : {
# 		"lastElectionReason" : "electionTimeout",
# 		"lastElectionDate" : ISODate("2020-05-01T17:20:09.164Z"),
# 		"electionTerm" : NumberLong(1),
# 		"lastCommittedOpTimeAtElection" : {
# 			"ts" : Timestamp(0, 0),
# 			"t" : NumberLong(-1)
# 		},
# 		"lastSeenOpTimeAtElection" : {
# 			"ts" : Timestamp(1588353599, 1),
# 			"t" : NumberLong(-1)
# 		},
# 		"numVotesNeeded" : 2,
# 		"priorityAtElection" : 1,
# 		"electionTimeoutMillis" : NumberLong(10000),
# 		"numCatchUpOps" : NumberLong(0),
# 		"newTermStartDate" : ISODate("2020-05-01T17:20:09.181Z"),
# 		"wMajorityWriteAvailabilityDate" : ISODate("2020-05-01T17:20:10.209Z")
# 	},
# 	"members" : [
# 		{
# 			"_id" : 0,
# 			"name" : "shard01-a:27017",
# 			"health" : 1,
# 			"state" : 1,
# 			"stateStr" : "PRIMARY",
# 			"uptime" : 1368,
# 			"optime" : {
# 				"ts" : Timestamp(1588354709, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:38:29Z"),
# 			"syncingTo" : "",
# 			"syncSourceHost" : "",
# 			"syncSourceId" : -1,
# 			"infoMessage" : "",
# 			"electionTime" : Timestamp(1588353609, 1),
# 			"electionDate" : ISODate("2020-05-01T17:20:09Z"),
# 			"configVersion" : 1,
# 			"self" : true,
# 			"lastHeartbeatMessage" : ""
# 		},
# 		{
# 			"_id" : 1,
# 			"name" : "shard01-b:27017",
# 			"health" : 1,
# 			"state" : 2,
# 			"stateStr" : "SECONDARY",
# 			"uptime" : 1110,
# 			"optime" : {
# 				"ts" : Timestamp(1588354699, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDurable" : {
# 				"ts" : Timestamp(1588354699, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:38:19Z"),
# 			"optimeDurableDate" : ISODate("2020-05-01T17:38:19Z"),
# 			"lastHeartbeat" : ISODate("2020-05-01T17:38:28.263Z"),
# 			"lastHeartbeatRecv" : ISODate("2020-05-01T17:38:29.252Z"),
# 			"pingMs" : NumberLong(0),
# 			"lastHeartbeatMessage" : "",
# 			"syncingTo" : "shard01-a:27017",
# 			"syncSourceHost" : "shard01-a:27017",
# 			"syncSourceId" : 0,
# 			"infoMessage" : "",
# 			"configVersion" : 1
# 		},
# 		{
# 			"_id" : 2,
# 			"name" : "shard01-c:27017",
# 			"health" : 1,
# 			"state" : 2,
# 			"stateStr" : "SECONDARY",
# 			"uptime" : 1110,
# 			"optime" : {
# 				"ts" : Timestamp(1588354699, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDurable" : {
# 				"ts" : Timestamp(1588354699, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:38:19Z"),
# 			"optimeDurableDate" : ISODate("2020-05-01T17:38:19Z"),
# 			"lastHeartbeat" : ISODate("2020-05-01T17:38:28.263Z"),
# 			"lastHeartbeatRecv" : ISODate("2020-05-01T17:38:29.252Z"),
# 			"pingMs" : NumberLong(0),
# 			"lastHeartbeatMessage" : "",
# 			"syncingTo" : "shard01-a:27017",
# 			"syncSourceHost" : "shard01-a:27017",
# 			"syncSourceId" : 0,
# 			"infoMessage" : "",
# 			"configVersion" : 1
# 		}
# 	],
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1588354709, 1),
# 	"$gleStats" : {
# 		"lastOpTime" : Timestamp(0, 0),
# 		"electionId" : ObjectId("7fffffff0000000000000001")
# 	},
# 	"lastCommittedOpTime" : Timestamp(1588354709, 1),
# 	"$configServerState" : {
# 		"opTime" : {
# 			"ts" : Timestamp(1588354698, 1),
# 			"t" : NumberLong(1)
# 		}
# 	},
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1588354709, 1),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %%
! docker exec -it rydell-shard-02-node-a bash -c "echo 'rs.status()' | mongo --port 27017"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("69434697-3506-4735-9ea4-f4ddae5049d1") }
# MongoDB server version: 4.0.18
# {
# 	"set" : "rs-shard-02",
# 	"date" : ISODate("2020-05-01T17:40:26.080Z"),
# 	"myState" : 1,
# 	"term" : NumberLong(1),
# 	"syncingTo" : "",
# 	"syncSourceHost" : "",
# 	"syncSourceId" : -1,
# 	"heartbeatIntervalMillis" : NumberLong(2000),
# 	"optimes" : {
# 		"lastCommittedOpTime" : {
# 			"ts" : Timestamp(1588354822, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"readConcernMajorityOpTime" : {
# 			"ts" : Timestamp(1588354822, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"appliedOpTime" : {
# 			"ts" : Timestamp(1588354822, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"durableOpTime" : {
# 			"ts" : Timestamp(1588354822, 1),
# 			"t" : NumberLong(1)
# 		}
# 	},
# 	"lastStableCheckpointTimestamp" : Timestamp(1588354812, 1),
# 	"electionCandidateMetrics" : {
# 		"lastElectionReason" : "electionTimeout",
# 		"lastElectionDate" : ISODate("2020-05-01T17:20:11.874Z"),
# 		"electionTerm" : NumberLong(1),
# 		"lastCommittedOpTimeAtElection" : {
# 			"ts" : Timestamp(0, 0),
# 			"t" : NumberLong(-1)
# 		},
# 		"lastSeenOpTimeAtElection" : {
# 			"ts" : Timestamp(1588353601, 1),
# 			"t" : NumberLong(-1)
# 		},
# 		"numVotesNeeded" : 2,
# 		"priorityAtElection" : 1,
# 		"electionTimeoutMillis" : NumberLong(10000),
# 		"numCatchUpOps" : NumberLong(0),
# 		"newTermStartDate" : ISODate("2020-05-01T17:20:11.893Z"),
# 		"wMajorityWriteAvailabilityDate" : ISODate("2020-05-01T17:20:12.969Z")
# 	},
# 	"members" : [
# 		{
# 			"_id" : 0,
# 			"name" : "shard02-a:27017",
# 			"health" : 1,
# 			"state" : 1,
# 			"stateStr" : "PRIMARY",
# 			"uptime" : 1485,
# 			"optime" : {
# 				"ts" : Timestamp(1588354822, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:40:22Z"),
# 			"syncingTo" : "",
# 			"syncSourceHost" : "",
# 			"syncSourceId" : -1,
# 			"infoMessage" : "",
# 			"electionTime" : Timestamp(1588353611, 1),
# 			"electionDate" : ISODate("2020-05-01T17:20:11Z"),
# 			"configVersion" : 1,
# 			"self" : true,
# 			"lastHeartbeatMessage" : ""
# 		},
# 		{
# 			"_id" : 1,
# 			"name" : "shard02-b:27017",
# 			"health" : 1,
# 			"state" : 2,
# 			"stateStr" : "SECONDARY",
# 			"uptime" : 1224,
# 			"optime" : {
# 				"ts" : Timestamp(1588354822, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDurable" : {
# 				"ts" : Timestamp(1588354822, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:40:22Z"),
# 			"optimeDurableDate" : ISODate("2020-05-01T17:40:22Z"),
# 			"lastHeartbeat" : ISODate("2020-05-01T17:40:25.037Z"),
# 			"lastHeartbeatRecv" : ISODate("2020-05-01T17:40:26.036Z"),
# 			"pingMs" : NumberLong(0),
# 			"lastHeartbeatMessage" : "",
# 			"syncingTo" : "shard02-a:27017",
# 			"syncSourceHost" : "shard02-a:27017",
# 			"syncSourceId" : 0,
# 			"infoMessage" : "",
# 			"configVersion" : 1
# 		},
# 		{
# 			"_id" : 2,
# 			"name" : "shard02-c:27017",
# 			"health" : 1,
# 			"state" : 2,
# 			"stateStr" : "SECONDARY",
# 			"uptime" : 1224,
# 			"optime" : {
# 				"ts" : Timestamp(1588354822, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDurable" : {
# 				"ts" : Timestamp(1588354822, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:40:22Z"),
# 			"optimeDurableDate" : ISODate("2020-05-01T17:40:22Z"),
# 			"lastHeartbeat" : ISODate("2020-05-01T17:40:25.037Z"),
# 			"lastHeartbeatRecv" : ISODate("2020-05-01T17:40:26.030Z"),
# 			"pingMs" : NumberLong(0),
# 			"lastHeartbeatMessage" : "",
# 			"syncingTo" : "shard02-a:27017",
# 			"syncSourceHost" : "shard02-a:27017",
# 			"syncSourceId" : 0,
# 			"infoMessage" : "",
# 			"configVersion" : 1
# 		}
# 	],
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1588354822, 1),
# 	"$gleStats" : {
# 		"lastOpTime" : Timestamp(0, 0),
# 		"electionId" : ObjectId("7fffffff0000000000000001")
# 	},
# 	"lastCommittedOpTime" : Timestamp(1588354822, 1),
# 	"$configServerState" : {
# 		"opTime" : {
# 			"ts" : Timestamp(1588354817, 2),
# 			"t" : NumberLong(1)
# 		}
# 	},
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1588354822, 1),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %%
! docker exec -it rydell-shard-03-node-a bash -c "echo 'rs.status()' | mongo --port 27017"
# Out:
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("030be440-49ec-4a8b-8622-630bac7f30a6") }
# MongoDB server version: 4.0.18
# {
# 	"set" : "rs-shard-03",
# 	"date" : ISODate("2020-05-01T17:40:55.367Z"),
# 	"myState" : 1,
# 	"term" : NumberLong(1),
# 	"syncingTo" : "",
# 	"syncSourceHost" : "",
# 	"syncSourceId" : -1,
# 	"heartbeatIntervalMillis" : NumberLong(2000),
# 	"optimes" : {
# 		"lastCommittedOpTime" : {
# 			"ts" : Timestamp(1588354845, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"readConcernMajorityOpTime" : {
# 			"ts" : Timestamp(1588354845, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"appliedOpTime" : {
# 			"ts" : Timestamp(1588354845, 1),
# 			"t" : NumberLong(1)
# 		},
# 		"durableOpTime" : {
# 			"ts" : Timestamp(1588354845, 1),
# 			"t" : NumberLong(1)
# 		}
# 	},
# 	"lastStableCheckpointTimestamp" : Timestamp(1588354815, 1),
# 	"electionCandidateMetrics" : {
# 		"lastElectionReason" : "electionTimeout",
# 		"lastElectionDate" : ISODate("2020-05-01T17:20:15.713Z"),
# 		"electionTerm" : NumberLong(1),
# 		"lastCommittedOpTimeAtElection" : {
# 			"ts" : Timestamp(0, 0),
# 			"t" : NumberLong(-1)
# 		},
# 		"lastSeenOpTimeAtElection" : {
# 			"ts" : Timestamp(1588353605, 1),
# 			"t" : NumberLong(-1)
# 		},
# 		"numVotesNeeded" : 2,
# 		"priorityAtElection" : 1,
# 		"electionTimeoutMillis" : NumberLong(10000),
# 		"numCatchUpOps" : NumberLong(0),
# 		"newTermStartDate" : ISODate("2020-05-01T17:20:15.728Z"),
# 		"wMajorityWriteAvailabilityDate" : ISODate("2020-05-01T17:20:16.612Z")
# 	},
# 	"members" : [
# 		{
# 			"_id" : 0,
# 			"name" : "shard03-a:27017",
# 			"health" : 1,
# 			"state" : 1,
# 			"stateStr" : "PRIMARY",
# 			"uptime" : 1514,
# 			"optime" : {
# 				"ts" : Timestamp(1588354845, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:40:45Z"),
# 			"syncingTo" : "",
# 			"syncSourceHost" : "",
# 			"syncSourceId" : -1,
# 			"infoMessage" : "",
# 			"electionTime" : Timestamp(1588353615, 1),
# 			"electionDate" : ISODate("2020-05-01T17:20:15Z"),
# 			"configVersion" : 1,
# 			"self" : true,
# 			"lastHeartbeatMessage" : ""
# 		},
# 		{
# 			"_id" : 1,
# 			"name" : "shard03-b:27017",
# 			"health" : 1,
# 			"state" : 2,
# 			"stateStr" : "SECONDARY",
# 			"uptime" : 1249,
# 			"optime" : {
# 				"ts" : Timestamp(1588354845, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDurable" : {
# 				"ts" : Timestamp(1588354845, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:40:45Z"),
# 			"optimeDurableDate" : ISODate("2020-05-01T17:40:45Z"),
# 			"lastHeartbeat" : ISODate("2020-05-01T17:40:55.020Z"),
# 			"lastHeartbeatRecv" : ISODate("2020-05-01T17:40:53.784Z"),
# 			"pingMs" : NumberLong(1),
# 			"lastHeartbeatMessage" : "",
# 			"syncingTo" : "shard03-a:27017",
# 			"syncSourceHost" : "shard03-a:27017",
# 			"syncSourceId" : 0,
# 			"infoMessage" : "",
# 			"configVersion" : 1
# 		},
# 		{
# 			"_id" : 2,
# 			"name" : "shard03-c:27017",
# 			"health" : 1,
# 			"state" : 2,
# 			"stateStr" : "SECONDARY",
# 			"uptime" : 1249,
# 			"optime" : {
# 				"ts" : Timestamp(1588354845, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDurable" : {
# 				"ts" : Timestamp(1588354845, 1),
# 				"t" : NumberLong(1)
# 			},
# 			"optimeDate" : ISODate("2020-05-01T17:40:45Z"),
# 			"optimeDurableDate" : ISODate("2020-05-01T17:40:45Z"),
# 			"lastHeartbeat" : ISODate("2020-05-01T17:40:55.021Z"),
# 			"lastHeartbeatRecv" : ISODate("2020-05-01T17:40:53.784Z"),
# 			"pingMs" : NumberLong(0),
# 			"lastHeartbeatMessage" : "",
# 			"syncingTo" : "shard03-a:27017",
# 			"syncSourceHost" : "shard03-a:27017",
# 			"syncSourceId" : 0,
# 			"infoMessage" : "",
# 			"configVersion" : 1
# 		}
# 	],
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1588354845, 1),
# 	"$gleStats" : {
# 		"lastOpTime" : Timestamp(0, 0),
# 		"electionId" : ObjectId("7fffffff0000000000000001")
# 	},
# 	"lastCommittedOpTime" : Timestamp(1588354845, 1),
# 	"$configServerState" : {
# 		"opTime" : {
# 			"ts" : Timestamp(1588354848, 2),
# 			"t" : NumberLong(1)
# 		}
# 	},
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1588354848, 2),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }
# bye

# %% [markdown]
# ### Check database status

# %%
docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec router01 mongo --port 27017
use MyDatabase
db.stats()
db.MyCollection.getShardDistribution()

# %% [raw]
# adzarei@adzarei-mac:mongo (GAI-TP2) $ docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec router01 mongo --port 27017
# MongoDB shell version v4.0.18
# connecting to: mongodb://127.0.0.1:27017/?gssapiServiceName=mongodb
# Implicit session: session { "id" : UUID("31ec6fe2-fb35-4805-ae01-82f61fbd578e") }
# MongoDB server version: 4.0.18
# Server has startup warnings:
# 2020-05-01T17:15:40.112+0000 I CONTROL  [main]
# 2020-05-01T17:15:40.112+0000 I CONTROL  [main] ** WARNING: Access control is not enabled for the database.
# 2020-05-01T17:15:40.112+0000 I CONTROL  [main] **          Read and write access to data and configuration is unrestricted.
# 2020-05-01T17:15:40.112+0000 I CONTROL  [main]

# %% [raw]
# mongos> use MyDatabase
# switched to db MyDatabase

# %% [raw]
# mongos> db.stats()
# {
#         "raw" : {
#                 "rs-shard-01/shard01-a:27017,shard01-b:27017,shard01-c:27017" : {
#                         "db" : "MyDatabase",
#                         "collections" : 1,
#                         "views" : 0,
#                         "objects" : 0,
#                         "avgObjSize" : 0,
#                         "dataSize" : 0,
#                         "storageSize" : 4096,
#                         "numExtents" : 0,
#                         "indexes" : 2,
#                         "indexSize" : 8192,
#                         "fsUsedSize" : 40384991232,
#                         "fsTotalSize" : 62725623808,
#                         "ok" : 1
#                 },
#                 "rs-shard-02/shard02-a:27017,shard02-b:27017,shard02-c:27017" : {
#                         "db" : "MyDatabase",
#                         "collections" : 1,
#                         "views" : 0,
#                         "objects" : 0,
#                         "avgObjSize" : 0,
#                         "dataSize" : 0,
#                         "storageSize" : 4096,
#                         "numExtents" : 0,
#                         "indexes" : 2,
#                         "indexSize" : 8192,
#                         "fsUsedSize" : 40384991232,
#                         "fsTotalSize" : 62725623808,
#                         "ok" : 1
#                 },
#                 "rs-shard-03/shard03-a:27017,shard03-b:27017,shard03-c:27017" : {
#                         "db" : "MyDatabase",
#                         "collections" : 1,
#                         "views" : 0,
#                         "objects" : 0,
#                         "avgObjSize" : 0,
#                         "dataSize" : 0,
#                         "storageSize" : 4096,
#                         "numExtents" : 0,
#                         "indexes" : 2,
#                         "indexSize" : 8192,
#                         "fsUsedSize" : 40384991232,
#                         "fsTotalSize" : 62725623808,
#                         "ok" : 1
#                 }
#         },
#         "objects" : 0,
#         "avgObjSize" : 0,
#         "dataSize" : 0,
#         "storageSize" : 12288,
#         "numExtents" : 0,
#         "indexes" : 6,
#         "indexSize" : 24576,
#         "fileSize" : 0,
#         "extentFreeList" : {
#                 "num" : 0,
#                 "totalSize" : 0
#         },
#         "ok" : 1,
#         "operationTime" : Timestamp(1588355899, 1),
#         "$clusterTime" : {
#                 "clusterTime" : Timestamp(1588355899, 1),
#                 "signature" : {
#                         "hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
#                         "keyId" : NumberLong(0)
#                 }
#         }
# }

# %% [raw]
# mongos> db.MyCollection.getShardDistribution()
#
# Shard rs-shard-01 at rs-shard-01/shard01-a:27017,shard01-b:27017,shard01-c:27017
#  data : 0B docs : 0 chunks : 2
#  estimated data per chunk : 0B
#  estimated docs per chunk : 0
#
# Shard rs-shard-03 at rs-shard-03/shard03-a:27017,shard03-b:27017,shard03-c:27017
#  data : 0B docs : 0 chunks : 2
#  estimated data per chunk : 0B
#  estimated docs per chunk : 0
#
# Shard rs-shard-02 at rs-shard-02/shard02-a:27017,shard02-b:27017,shard02-c:27017
#  data : 0B docs : 0 chunks : 2
#  estimated data per chunk : 0B
#  estimated docs per chunk : 0
#
# Totals
#  data : 0B docs : 0 chunks : 6
#  Shard rs-shard-01 contains 0% data, 0% docs in cluster, avg obj size on shard : 0B
#  Shard rs-shard-03 contains 0% data, 0% docs in cluster, avg obj size on shard : 0B
#  Shard rs-shard-02 contains 0% data, 0% docs in cluster, avg obj size on shard : 0B

# %% [markdown]
# ## Ejercicios

# %% [markdown]
# - 1 Conectarse a la BD

# %% [raw]
# docker-compose -f mongodb-cluster-docker-compose/docker-compose.yml exec router01 mongo --port 27017

# %% [markdown]
# - Acceder a la BD MyDatabase y comprobar que existe la colección MyCollection

# %% [raw]
# mongos> use MyDatabase
# switched to db MyDatabase

# %% [raw]
# mongos> db.MyCollection.exists()
# {
#         "name" : "MyCollection",
#         "type" : "collection",
#         "options" : {
#
#         },
#         "info" : {
#                 "readOnly" : false,
#                 "uuid" : UUID("694b23c4-9559-4324-9895-fe9a8e96aa54")
#         },
#         "idIndex" : {
#                 "v" : 2,
#                 "key" : {
#                         "_id" : 1
#                 },
#                 "name" : "_id_",
#                 "ns" : "MyDatabase.MyCollection"
#         }
# }

# %% [markdown]
# - Poblar la colección MyCollection
#
# Usar:
# > for (var i=0;i<2000;i++){db.MyCollection.insert({‘supplierId’:i})}

# %% [raw]
# mongos> for (var i=0;i<2000;i++){db.MyCollection.insert({'supplierId':i})}
# WriteResult({ "nInserted" : 1 })

# %% [markdown]
# - ¿Qué hemos hecho en la operación anterior?

# %% [markdown]
# > Se han insertado 2000 documentos en MyCollection con supplierId de 0 a 1999.

# %% [markdown]
# - ¿Por qué hemos utilizado el campo “supplierId” en concreto?

# %% [markdown]
# > Se ha usado ese campo porque es el Shard Key. <br/>
# > Como supplierId es la Shard Key, los 2000 documentos se han repartido equitativamente entre los 3 shards.

# %% [raw]
# mongos> db.MyCollection.getShardDistribution()
#
# Shard rs-shard-03 at rs-shard-03/shard03-a:27017,shard03-b:27017,shard03-c:27017
#  data : 27KiB docs : 682 chunks : 2
#  estimated data per chunk : 13KiB
#  estimated docs per chunk : 341
#
# Shard rs-shard-02 at rs-shard-02/shard02-a:27017,shard02-b:27017,shard02-c:27017
#  data : 28KiB docs : 689 chunks : 2
#  estimated data per chunk : 14KiB
#  estimated docs per chunk : 344
#
# Shard rs-shard-01 at rs-shard-01/shard01-a:27017,shard01-b:27017,shard01-c:27017
#  data : 25KiB docs : 629 chunks : 2
#  estimated data per chunk : 12KiB
#  estimated docs per chunk : 314
#
# Totals
#  data : 82KiB docs : 2000 chunks : 6
#  Shard rs-shard-03 contains 34.1% data, 34.1% docs in cluster, avg obj size on shard : 42B
#  Shard rs-shard-02 contains 34.44% data, 34.44% docs in cluster, avg obj size on shard : 42B
#  Shard rs-shard-01 contains 31.45% data, 31.45% docs in cluster, avg obj size on shard : 42B

# %% [markdown]
# > Como se puede ver en la celda de arriba, cada Shard ha alamacenado ,mas o menos, el mismo número de documentos.

# %% [markdown]
# - Realizar una consulta “find()” genérica sobre la colección y utilizar el método que se ha estudiado en la parte teórica para la monitorización de consultas, especificando la opción "executionStats".

# %% [raw]
# mongos> db.MyCollection.find().explain("executionStats")
# {
# 	"queryPlanner" : {
# 		"mongosPlannerVersion" : 1,
# 		"winningPlan" : {
# 			"stage" : "SHARD_MERGE",
# 			"shards" : [
# 				{
# 					"shardName" : "rs-shard-03",
# 					"connectionString" : "rs-shard-03/shard03-a:27017,shard03-b:27017,shard03-c:27017",
# 					"serverInfo" : {
# 						"host" : "b2510fd6a3fc",
# 						"port" : 27017,
# 						"version" : "4.0.18",
# 						"gitVersion" : "6883bdfb8b8cff32176b1fd176df04da9165fd67"
# 					},
# 					"plannerVersion" : 1,
# 					"namespace" : "MyDatabase.MyCollection",
# 					"indexFilterSet" : false,
# 					"parsedQuery" : {
#
# 					},
# 					"winningPlan" : {
# 						"stage" : "SHARDING_FILTER",
# 						"inputStage" : {
# 							"stage" : "COLLSCAN",
# 							"direction" : "forward"
# 						}
# 					},
# 					"rejectedPlans" : [ ]
# 				},
# 				{
# 					"shardName" : "rs-shard-01",
# 					"connectionString" : "rs-shard-01/shard01-a:27017,shard01-b:27017,shard01-c:27017",
# 					"serverInfo" : {
# 						"host" : "deb59354c975",
# 						"port" : 27017,
# 						"version" : "4.0.18",
# 						"gitVersion" : "6883bdfb8b8cff32176b1fd176df04da9165fd67"
# 					},
# 					"plannerVersion" : 1,
# 					"namespace" : "MyDatabase.MyCollection",
# 					"indexFilterSet" : false,
# 					"parsedQuery" : {
#
# 					},
# 					"winningPlan" : {
# 						"stage" : "SHARDING_FILTER",
# 						"inputStage" : {
# 							"stage" : "COLLSCAN",
# 							"direction" : "forward"
# 						}
# 					},
# 					"rejectedPlans" : [ ]
# 				},
# 				{
# 					"shardName" : "rs-shard-02",
# 					"connectionString" : "rs-shard-02/shard02-a:27017,shard02-b:27017,shard02-c:27017",
# 					"serverInfo" : {
# 						"host" : "6d33b6ee39d2",
# 						"port" : 27017,
# 						"version" : "4.0.18",
# 						"gitVersion" : "6883bdfb8b8cff32176b1fd176df04da9165fd67"
# 					},
# 					"plannerVersion" : 1,
# 					"namespace" : "MyDatabase.MyCollection",
# 					"indexFilterSet" : false,
# 					"parsedQuery" : {
#
# 					},
# 					"winningPlan" : {
# 						"stage" : "SHARDING_FILTER",
# 						"inputStage" : {
# 							"stage" : "COLLSCAN",
# 							"direction" : "forward"
# 						}
# 					},
# 					"rejectedPlans" : [ ]
# 				}
# 			]
# 		}
# 	},
# 	"executionStats" : {
# 		"nReturned" : 2000,
# 		"executionTimeMillis" : 6,
# 		"totalKeysExamined" : 0,
# 		"totalDocsExamined" : 2000,
# 		"executionStages" : {
# 			"stage" : "SHARD_MERGE",
# 			"nReturned" : 2000,
# 			"executionTimeMillis" : 6,
# 			"totalKeysExamined" : 0,
# 			"totalDocsExamined" : 2000,
# 			"totalChildMillis" : NumberLong(8),
# 			"shards" : [
# 				{
# 					"shardName" : "rs-shard-03",
# 					"executionSuccess" : true,
# 					"executionStages" : {
# 						"stage" : "SHARDING_FILTER",
# 						"nReturned" : 682,
# 						"executionTimeMillisEstimate" : 0,
# 						"works" : 684,
# 						"advanced" : 682,
# 						"needTime" : 1,
# 						"needYield" : 0,
# 						"saveState" : 5,
# 						"restoreState" : 5,
# 						"isEOF" : 1,
# 						"invalidates" : 0,
# 						"chunkSkips" : 0,
# 						"inputStage" : {
# 							"stage" : "COLLSCAN",
# 							"nReturned" : 682,
# 							"executionTimeMillisEstimate" : 0,
# 							"works" : 684,
# 							"advanced" : 682,
# 							"needTime" : 1,
# 							"needYield" : 0,
# 							"saveState" : 5,
# 							"restoreState" : 5,
# 							"isEOF" : 1,
# 							"invalidates" : 0,
# 							"direction" : "forward",
# 							"docsExamined" : 682
# 						}
# 					}
# 				},
# 				{
# 					"shardName" : "rs-shard-01",
# 					"executionSuccess" : true,
# 					"executionStages" : {
# 						"stage" : "SHARDING_FILTER",
# 						"nReturned" : 629,
# 						"executionTimeMillisEstimate" : 0,
# 						"works" : 631,
# 						"advanced" : 629,
# 						"needTime" : 1,
# 						"needYield" : 0,
# 						"saveState" : 4,
# 						"restoreState" : 4,
# 						"isEOF" : 1,
# 						"invalidates" : 0,
# 						"chunkSkips" : 0,
# 						"inputStage" : {
# 							"stage" : "COLLSCAN",
# 							"nReturned" : 629,
# 							"executionTimeMillisEstimate" : 0,
# 							"works" : 631,
# 							"advanced" : 629,
# 							"needTime" : 1,
# 							"needYield" : 0,
# 							"saveState" : 4,
# 							"restoreState" : 4,
# 							"isEOF" : 1,
# 							"invalidates" : 0,
# 							"direction" : "forward",
# 							"docsExamined" : 629
# 						}
# 					}
# 				},
# 				{
# 					"shardName" : "rs-shard-02",
# 					"executionSuccess" : true,
# 					"executionStages" : {
# 						"stage" : "SHARDING_FILTER",
# 						"nReturned" : 689,
# 						"executionTimeMillisEstimate" : 0,
# 						"works" : 691,
# 						"advanced" : 689,
# 						"needTime" : 1,
# 						"needYield" : 0,
# 						"saveState" : 5,
# 						"restoreState" : 5,
# 						"isEOF" : 1,
# 						"invalidates" : 0,
# 						"chunkSkips" : 0,
# 						"inputStage" : {
# 							"stage" : "COLLSCAN",
# 							"nReturned" : 689,
# 							"executionTimeMillisEstimate" : 0,
# 							"works" : 691,
# 							"advanced" : 689,
# 							"needTime" : 1,
# 							"needYield" : 0,
# 							"saveState" : 5,
# 							"restoreState" : 5,
# 							"isEOF" : 1,
# 							"invalidates" : 0,
# 							"direction" : "forward",
# 							"docsExamined" : 689
# 						}
# 					}
# 				}
# 			]
# 		}
# 	},
# 	"serverInfo" : {
# 		"host" : "c89fd5a0a7af",
# 		"port" : 27017,
# 		"version" : "4.0.18",
# 		"gitVersion" : "6883bdfb8b8cff32176b1fd176df04da9165fd67"
# 	},
# 	"ok" : 1,
# 	"operationTime" : Timestamp(1618173413, 1),
# 	"$clusterTime" : {
# 		"clusterTime" : Timestamp(1618173413, 1),
# 		"signature" : {
# 			"hash" : BinData(0,"AAAAAAAAAAAAAAAAAAAAAAAAAAA="),
# 			"keyId" : NumberLong(0)
# 		}
# 	}
# }

# %% [markdown]
# - ¿Qué resultados se obtienen?

# %% [markdown]
# > En la sección executionStages tenemos un nuevo stage que no se había visto antes: SHARD_MERGE.<br/>
# > Hay una nueva sección llamada shards quer nos proporciona estadísticas de cada SHARD, por ejemplo el nº de documentos devueltos. <br/>
# > La consulta ha accedido a los 3 shards, ha hecho un stage SHARDING_FILTER y por último un COLLSCAN.

# %% [markdown]
# - ¿Cuál es la explicación en lo relativo al sharding?

# %% [markdown]
# > Como los 2000 documentos se han repartido equitativamente entre cada SHARD ( ~ 666 documentos por SHARD ), la consulta ha tenido que acceder a los 3 shards y recoger los documentos que contenía cada uno. <br/>
# > En primer lugar se ha realizdo una operación de filtrado SHARDING_FILTER que descarta los documentos huerfanos de cada SHARD<br/>
# > En segundo lugar se ha realizado un COLLSCAN para buscar, en cada shard, los documentos.
# > por último, se han juntado los resultados en el stage SHARD_MERGE.

# %% [markdown]
# ## Conclusiones:
#
# Considero que la TP2 ha sido una prueba muy completa de introducción a Mongo DB. He podido aprender sobre cómo diseñar BD Documentales sin caer en patrones relacionales como venía estando acostumbrado. He aprendido sobre la importancia de los índices en Mongo DB y he descubierto que se pueden usar mas de uno simultaneamente. El ejercicio 2 me ha enseñado la potencia y flexibilidad de Mongo DB a la hora de realizar búsquedas. En este ejercico he aprendido el concepto de las agregaciones en Mongo, que aunque no las terminaba de entender al inicio, creo que las he acabado dominando. Por último he encontrado muy interesante el ejercicio 3 que me ha brindado una visión de cómo funcionan los distintos servicios en un cluster de Mongo DB.
#
# Como punto de mejora sólo puedo decir 1: Añadir un apartado al ejercicio 3 para investigar la replicación dentro de un mismo SHARD y la tolerancia a fallos de Mongo.
