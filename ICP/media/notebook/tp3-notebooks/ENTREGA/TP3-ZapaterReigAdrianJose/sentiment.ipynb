# %% [markdown]
# # Ejercicio 3 (análisis de sentimiento): (3 puntos)
# Se pide desarrollar un notebook de Jupyter, denominado “sentiment.ipynb”, en el que se utilice como fuente de datos Kafka, y en concreto el topic kafkaTwitter. Para cada nuevo tweet que llegue al sistema, se analizará su polaridad dividiendo el tweet por palabras y realizando la suma de la polaridad de todas las palabras que aparezcan en los ficheros “positive_lex.txt” y “negative_lex.txt”. Las palabras del lexicon negativo tienen un signo menos delante, por lo que restarán a la puntuación final del tweet. Si ninguna de las palabras del tweet está almacenada en los ficheros proporcionados (o si las puntuaciones de las palabras positivas y negativas se anulan), la polaridad del tweet será 0.
#
# La salida del sistema ha de imprimirse cada segundo, y consistirá en una línea por cada tweet recibido, que contenga el texto del propio tweet, a continuación la puntuacin de su polaridad, y la palabra “NEUTRO” si la puntuación es igual 0, “POSITIVO” si es mayor que 0, y “NEGATIVO” si es menor que 0.

# %%
import findspark
findspark.init('/opt/spark')

# %%
import os
os.environ['JAVA_HOME'] = '/Library/Java/JavaVirtualMachines/jdk1.8.0_171.jdk/Contents/Home/jre'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--master local[*] --packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.4.4 pyspark-shell'

# %%
import pyspark
import pyspark.streaming
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

# %%
spark = SparkSession.builder.appName("hashtags").master("local[*]").getOrCreate()

# 1s de batchDuration
ssc = StreamingContext(spark.sparkContext, 1)

ssc.checkpoint("checkpoint")

# %% [markdown]
# ## Empezamos por cargar los datos de positive_lex.txt y negative_lex.txt a un DataFrame

# %%
# Parametrizar con ruta donde están los ficheros.
neg_file_path = "DocumentosTP3/negative_lex.txt"
raw_neg_lex = spark.read.option("header", "false").csv(neg_file_path)

# %%
raw_neg_lex.show(5)
# Out:
# +------------------+
# |               _c0|
# +------------------+
# |     abatir -0.554|
# | abochornado -0.25|
# |   abochornar -0.5|
# |abominación -0.425|
# |  aborrecer -0.625|
# +------------------+
# only showing top 5 rows

# %%
# Parametrizar con ruta donde están los ficheros.
pos_file_path = "DocumentosTP3/positive_lex.txt"
raw_pos_lex = spark.read.option("header", "false").csv(pos_file_path)

# %%
raw_pos_lex.show(5)
# Out:
# +---------------+
# |            _c0|
# +---------------+
# | acertado 0.708|
# |admirable 0.906|
# |admiración 0.45|
# |   admirar 0.75|
# | afectivo 0.375|
# +---------------+
# only showing top 5 rows

# %% [markdown]
# Separamos la información en 2 columnas para que sea mas facil de procesar.

# %%
from pyspark.sql import Column, DataFrame, functions

# %%
neg_col = functions.split(raw_neg_lex._c0," ")
neg_lex = raw_neg_lex.select(neg_col[0].alias("word"), neg_col[1].alias("puntuacion"))

# %%
neg_lex.show(5)
# Out:
# +-----------+----------+
# |       word|puntuacion|
# +-----------+----------+
# |     abatir|    -0.554|
# |abochornado|     -0.25|
# | abochornar|      -0.5|
# |abominación|    -0.425|
# |  aborrecer|    -0.625|
# +-----------+----------+
# only showing top 5 rows

# %%
pos_col = functions.split(raw_pos_lex._c0," ")
pos_lex = raw_pos_lex.select(pos_col[0].alias("word"), pos_col[1].alias("puntuacion"))

# %%
pos_lex.show(5)
# Out:
# +----------+----------+
# |      word|puntuacion|
# +----------+----------+
# |  acertado|     0.708|
# | admirable|     0.906|
# |admiración|      0.45|
# |   admirar|      0.75|
# |  afectivo|     0.375|
# +----------+----------+
# only showing top 5 rows

# %% [markdown]
# ## Vamos a cruzar las palabras de los tweets con las tablas.

# %% [markdown]
# Primero debemos separar el DStream en los distintos tweets y quedarnos solo con el mensaje.

# %%
# DStream con el batch de 5s de Kafka.
kafkaStream = KafkaUtils.createStream(ssc,zkQuorum='localhost:2181',groupId="group_1" , topics={'kafkaTwitter':2})

# %%
#tweet_stream = kafkaStream.map(lambda tweet: tweet[1],)

# %% [markdown]
# Calculamos la puntuación por palabra.

# %%
pos_dict = {}
for row in pos_lex.collect():
      pos_dict[row.word] = float(row.puntuacion)
pos_dict
# Out:
# {'acertado': 0.708,
#  'admirable': 0.906,
#  'admiración': 0.45,
#  'admirar': 0.75,
#  'afectivo': 0.375,
#  'afecto': 0.321,
#  'afectuoso': 0.563,
#  'afición': 0.5,
#  'afortunado': 0.813,
#  'agradable': 0.75,
#  'agradecido': 0.5,
#  'alegrar': 0.458,
#  'alegre': 0.661,
#  'alentador': 0.25,
#  'alentar': 0.275,
#  'amable': 0.688,
#  'amar': 1.0,
#  'amistoso': 0.708,
#  'amor': 0.278,
#  'animado': 0.494,
#  'animar': 0.289,
#  'apacible': 0.313,
#  'apasionado': 0.469,
#  'apego': 0.375,
#  'aprecio': 0.344,
#  'aprobar': 0.375,
#  'ardiente': 0.313,
#  'atractivo': 0.5,
#  'beneficio': 0.396,
#  'benevolencia': 0.438,
#  'benevolente': 0.313,
#  'bien': 0.792,
#  'bienestar': 0.531,
#  'bondad': 0.25,
#  'bonito': 0.75,
#  'buen': 0.734,
#  'bueno': 0.5,
#  'cariñoso': 0.438,
#  'cautivado': 0.438,
#  'cautivador': 0.594,
#  'cercano': 0.354,
#  'comodidad': 0.406,
#  'compañerismo': 0.25,
#  'competente': 0.589,
#  'complacencia': 0.688,
#  'complacer': 0.475,
#  'complaciente': 0.643,
#  'confianza': 0.375,
#  'confortar': 0.375,
#  'consolar': 0.375,
#  'contentarse': 0.375,
#  'contento': 0.5,
#  'correcto': 0.806,
#  'cortés': 0.667,
#  'cuidadoso': 0.521,
#  'cálido': 0.411,
#  'cándido': 0.35,
#  'cómodo': 0.469,
#  'decente': 0.571,
#  'deleitarse': 0.475,
#  'diestro': 0.625,
#  'disfrutar': 0.536,
#  'divertido': 0.653,
#  'divertir': 0.281,
#  'divertirse': 0.542,
#  'dulce': 0.518,
#  'emotivo': 0.313,
#  'encantado': 0.417,
#  'encantador': 0.833,
#  'entusiasmo': 0.661,
#  'entusiasta': 0.6,
#  'estima': 0.521,
#  'estimulante': 0.25,
#  'estimular': 0.262,
#  'euforia': 0.531,
#  'eufórico': 0.344,
#  'excelente': 0.75,
#  'excitante': 0.425,
#  'experto': 0.25,
#  'fascinación': 0.438,
#  'fascinante': 0.5,
#  'favorable': 0.844,
#  'favorecer': 0.268,
#  'felicidad': 0.708,
#  'feliz': 0.719,
#  'ferviente': 0.5,
#  'fiable': 0.75,
#  'firmeza': 0.278,
#  'gozar': 0.458,
#  'gracioso': 0.625,
#  'gratificante': 0.75,
#  'gustar': 0.406,
#  'gusto': 0.266,
#  'honorable': 0.583,
#  'honrado': 0.667,
#  'honrar': 0.5,
#  'hábil': 0.875,
#  'ideal': 0.425,
#  'idóneo': 0.7,
#  'interés': 0.321,
#  'jovial': 0.775,
#  'joya': 0.458,
#  'jubiloso': 0.563,
#  'justo': 0.675,
#  'júbilo': 0.542,
#  'magnífico': 0.804,
#  'mañoso': 0.563,
#  'minucioso': 0.438,
#  'optimismo': 0.458,
#  'optimista': 0.625,
#  'placentero': 0.875,
#  'plácido': 0.25,
#  'positivo': 0.594,
#  'preferencia': 0.281,
#  'prometedor': 0.875,
#  'provecho': 0.328,
#  'reconfortante': 0.375,
#  'recrear': 0.313,
#  'recto': 0.438,
#  'refrescar': 0.25,
#  'regocijado': 0.667,
#  'regocijar': 0.875,
#  'regocijarse': 0.313,
#  'regocijo': 0.25,
#  'respetable': 0.906,
#  'saludable': 0.768,
#  'sano': 0.8,
#  'satisfacer': 0.578,
#  'satisfactorio': 0.375,
#  'satisfecho': 0.6,
#  'seductor': 0.7,
#  'seguro': 0.375,
#  'sereno': 0.297,
#  'simpatía': 0.354,
#  'simpático': 0.653,
#  'solazar': 0.375,
#  'sonriente': 1.0,
#  'sosegado': 0.292,
#  'superior': 0.375,
#  'ternura': 0.313,
#  'tierno': 0.375,
#  'tranquilizar': 0.333,
#  'tónico': 0.375,
#  'utilidad': 0.344,
#  'vigorizante': 0.625,
#  'vigorizar': 0.375,
#  'útil': 0.25,
#  'adorador': 0.5,
#  'afectividad': 0.625,
#  'afectuosidad': 0.375,
#  'agradado': 0.75,
#  'agradar': 0.708,
#  'alborozar': 1.0,
#  'alegrarse': 1.0,
#  'altruista': 0.375,
#  'amativo': 0.25,
#  'amigable': 0.542,
#  'amoroso': 0.625,
#  'animarse': 0.25,
#  'aprobado': 0.625,
#  'aprobativo': 1.0,
#  'aprobatorio': 1.0,
#  'arrebatador': 0.875,
#  'autocomplacencia': 0.625,
#  'benefactor': 0.938,
#  'beneficencia': 0.688,
#  'beneficioso': 0.917,
#  'benéfico': 0.625,
#  'benévolo': 0.438,
#  'cariñosamente': 0.375,
#  'complacido': 0.438,
#  'confiadamente': 0.5,
#  'confort': 0.5,
#  'contentamiento': 0.5,
#  'convencido': 0.25,
#  'desahogado': 0.375,
#  'devoto': 0.5,
#  'embebecimiento': 0.5,
#  'embeleso': 0.375,
#  'embriagar': 0.5,
#  'encandilamiento': 0.313,
#  'esperanzador': 1.0,
#  'estimulador': 0.75,
#  'exuberancia': 0.625,
#  'exultación': 0.375,
#  'fervoroso': 0.75,
#  'fraternal': 0.375,
#  'fraterno': 0.375,
#  'fácil': 0.25,
#  'fácilmente': 0.25,
#  'gratificar': 0.417,
#  'gratitud': 0.417,
#  'habilidoso': 0.875,
#  'hilarante': 0.625,
#  'hilaridad': 0.375,
#  'jocundidad': 0.5,
#  'jovialidad': 0.583,
#  'lealtad': 0.313,
#  'motivar': 0.25,
#  'optimístico': 0.875,
#  'placidez': 0.25,
#  'predilección': 0.375,
#  'regocijador': 0.625,
#  'risueño': 0.833,
#  'saciable': 0.625,
#  'satisfacible': 0.625,
#  'suertudo': 0.75,
#  'tranquilizado': 0.5,
#  'tranquilizador': 0.313,
#  'triunfo': 0.25,
#  'triunfal': 0.375,
#  'triunfante': 0.563,
#  'ufano': 0.438,
#  'venturoso': 0.875,
#  'victorioso': 0.583,
#  'vigorizador': 0.625,
#  'vitorear': 0.375,
#  'acaudalar': 1.0,
#  'acogedor': 0.775,
#  'afable': 1.0,
#  'afortunadamente': 0.875,
#  'alabar': 1.0,
#  'amenidad': 1.0,
#  'apreciado': 0.875,
#  'armonioso': 0.792,
#  'bendito': 0.792,
#  'bonachón': 1.0,
#  'citable': 0.813,
#  'clamoroso': 1.0,
#  'clavado': 0.875,
#  'conmovido': 0.875,
#  'cooperativo': 0.875,
#  'célebre': 1.0,
#  'deleitoso': 0.875,
#  'destacable': 1.0,
#  'dotado': 0.875,
#  'encomiable': 1.0,
#  'esplendoroso': 1.0,
#  'espléndido': 0.771,
#  'exculpar': 0.875,
#  'famoso': 1.0,
#  'favorecedor': 0.875,
#  'filántropo': 0.375,
#  'finísimo': 0.875,
#  'glorioso': 0.833,
#  'harmonioso': 0.875,
#  'hermoso': 0.792,
#  'heroicidad': 1.0,
#  'heroísmo': 1.0,
#  'honorabilidad': 0.813,
#  'honorado': 0.875,
#  'idealizado': 0.875,
#  'juicioso': 0.833,
#  'laudable': 1.0,
#  'lindo': 0.875,
#  'loable': 1.0,
#  'magistral': 0.813,
#  'manitas': 0.875,
#  'medrar': 0.813,
#  'merecedor': 0.813,
#  'meritorio': 0.25,
#  'modoso': 0.875,
#  'modélico': 0.875,
#  'notable': 0.775,
#  'pacífico': 0.781,
#  'perfectamente': 0.875,
#  'preferente': 0.875,
#  'presentable': 0.875,
#  'prosperar': 0.813,
#  'prosperidad': 1.0,
#  'querúbico': 1.0,
#  'respetabilidad': 0.875,
#  'respetado': 0.875,
#  'respetar': 0.875,
#  'rubicundo': 0.813,
#  'salvamento': 1.0,
#  'talentoso': 0.875,
#  'ventajoso': 1.0,
#  'óptimo': 1.0,
#  'abordable': 0.75,
#  'adecuada': 0.75,
#  'adoptable': 0.75,
#  'afirmativo': 0.5,
#  'alcista': 0.5,
#  'ameno': 0.75,
#  'apegado': 0.75,
#  'arrojado': 0.75,
#  'beato': 0.75,
#  'bendecido': 0.75,
#  'beneficiarse': 0.75,
#  'bienaventuranza': 0.75,
#  'bienvenido': 0.75,
#  'bizarro': 0.75,
#  'canjeable': 0.75,
#  'carismático': 0.75,
#  'chistoso': 0.75,
#  'cognoscible': 0.75,
#  'confidente': 0.75,
#  'confirmador': 0.75,
#  'confirmante': 0.75,
#  'congruencia': 0.75,
#  'conocible': 0.75,
#  'constructivo': 0.75,
#  'corroborante': 0.75,
#  'curativo': 0.625,
#  'deseable': 0.75,
#  'dicha': 0.75,
#  'elegible': 0.75,
#  'enmendable': 0.75,
#  'entrañable': 0.75,
#  'escalable': 0.75,
#  'estandarizado': 0.75,
#  'estimado': 0.75,
#  'exhuberancia': 0.75,
#  'exitoso': 0.75,
#  'experimentado': 0.75,
#  'fastuoso': 0.75,
#  'fehaciente': 0.75,
#  'fidedigno': 0.75,
#  'fotogénico': 0.75,
#  'garboso': 0.75,
#  'grato': 0.75,
#  'guapo': 0.75,
#  'halagüeño': 0.75,
#  'harmonizado': 0.75,
#  'hedonístico': 0.75,
#  'hedónico': 0.75,
#  'honor': 0.75,
#  'honorablemente': 0.75,
#  'honorífico': 0.75,
#  'hospitalario': 0.75,
#  'idoneidad': 0.75,
#  'laudatorio': 0.75,
#  'mejoría': 0.75,
#  'panegírico': 0.375,
#  'perito': 0.375,
#  'plasticidad': 0.75,
#  'polifacético': 0.75,
#  'pujante': 0.75,
#  'realzado': 0.75,
#  'reconstructor': 0.75,
#  'reformable': 0.75,
#  'remediador': 0.75,
#  'reír': 0.75,
#  'saciado': 0.75,
#  'salubre': 0.75,
#  'sanador': 0.75,
#  'sublime': 0.75,
#  'valedero': 0.75,
#  'verificador': 0.75,
#  'veterano': 0.75,
#  'virtuosillo': 0.75,
#  'virtuoso': 0.75,
#  'voluntariamente': 0.75,
#  'abundante': 0.589,
#  'accesible': 0.607,
#  'aceptabilidad': 0.688,
#  'aceptable': 0.688,
#  'acomodado': 0.563,
#  'acompasado': 0.625,
#  'aconsejable': 0.625,
#  'acreditado': 0.667,
#  'adecuado': 0.656,
#  'administrable': 0.625,
#  'admirabilidad': 0.625,
#  'admirablemente': 0.625,
#  'admisible': 0.625,
#  'adornado': 0.625,
#  'afabilidad': 0.583,
#  'afectuosamente': 0.625,
#  'agrado': 0.625,
#  'alimenticio': 0.625,
#  'amabilidad': 0.547,
#  'angelical': 0.583,
#  'anglofilia': 0.625,
#  'antihelmíntico': 0.625,
#  'antimicrobiano': 0.625,
#  'apaciguable': 0.625,
#  'aplaudir': 0.625,
#  'apropiado': 0.656,
#  'aptitud': 0.542,
#  'apto': 0.557,
#  'apuesto': 0.688,
#  'asíduo': 0.625,
#  'atractividad': 0.625,
#  'atrayente': 0.583,
#  'autodidacta': 0.25,
#  'autoimpuesto': 0.625,
#  'auxiliar': 0.542,
#  'axénico': 0.625,
#  'bellaco': 0.625,
#  'bello': 0.708,
#  'bienaventurado': 0.625,
#  'brillantez': 0.594,
#  'bruñido': 0.25,
#  'caballero': 0.625,
#  'caballeroso': 0.625,
#  'cachondo': 0.625,
#  'campeón': 0.625,
#  'capaz': 0.634,
#  'casto': 0.563,
#  'catártico': 0.688,
#  'cauteloso': 0.521,
#  'cauto': 0.531,
#  'celebrado': 0.625,
#  'certificativo': 0.625,
#  'certificatorio': 0.625,
#  'chachi': 0.688,
#  'chic': 0.625,
#  'chusco': 0.625,
#  'circunspecto': 0.625,
#  'comedido': 0.563,
#  'comestible': 0.625,
#  'compatible': 0.531,
#  'conceptivo': 0.625,
#  'conciliación': 0.708,
#  'conciliado': 0.625,
#  'confortable': 0.625,
#  'congraciador': 0.563,
#  'congruente': 0.625,
#  'consagrado': 0.688,
#  'consensuado': 0.625,
#  'controlable': 0.625,
#  'convalidar': 0.625,
#  'conveniente': 0.659,
#  'copioso': 0.583,
#  'cordial': 0.646,
#  'cordura': 0.625,
#  'correctivo': 0.563,
#  'corregible': 0.625,
#  'creatividad': 0.625,
#  'creativo': 0.625,
#  'cualificado': 0.667,
#  'culto': 0.525,
#  'curativa': 0.625,
#  'célibe': 0.625,
#  'decencia': 0.542,
#  'decible': 0.625,
#  'decorado': 0.625,
#  'decoro': 0.625,
#  'decoroso': 0.708,
#  'deducible': 0.625,
#  'deferente': 0.625,
#  'demostrativo': 0.625,
#  'describible': 0.625,
#  'descriptible': 0.625,
#  'desenganchado': 0.625,
#  'desenterrado': 0.625,
#  'destreza': 0.525,
#  'detallado': 0.563,
#  'detenido': 0.25,
#  'digno': 0.667,
#  'disociar': 0.625,
#  'dispuesto': 0.563,
#  'distinguido': 0.55,
#  'divertidísimo': 0.625,
#  'docto': 0.563,
#  'domesticable': 0.625,
#  'edificante': 0.625,
#  'educable': 0.625,
#  'educado': 0.609,
#  'educativo': 0.563,
#  'efectividad': 0.563,
#  'eficaz': 0.583,
#  'eficiencia': 0.625,
#  'elástico': 0.6,
#  'embelesado': 0.563,
#  'enardecedor': 0.563,
#  'enciclopédico': 0.625,
#  'entregado': 0.625,
#  'entretenido': 0.667,
#  'entretenimiento': 0.531,
#  'equitativo': 0.625,
#  'erudito': 0.542,
#  'especializado': 0.708,
#  'especificable': 0.625,
#  'estimable': 0.563,
#  'eudemónico': 0.625,
#  'exacto': 0.625,
#  'expansivo': 0.6,
#  'explicable': 0.625,
#  'explícit': 0.625,
#  'expresable': 0.625,
#  'factible': 0.625,
#  'fecundo': 0.563,
#  'fenomenal': 0.563,
#  'fiel': 0.7,
#  'flamante': 0.625,
#  'fogosidad': 0.563,
#  'formalizado': 0.625,
#  'formativo': 0.625,
#  'formidable': 0.542,
#  'fortalecido': 0.625,
#  'frutal': 0.625,
#  'fulgor': 0.625,
#  'fértil': 0.563,
#  'galante': 0.625,
#  'galantear': 0.625,
#  'gallardo': 0.688,
#  'ganador': 0.625,
#  'generosa': 0.625,
#  'generosamente': 0.625,
#  'genial': 0.661,
#  'guay': 0.542,
#  'habilitante': 0.625,
#  'habitable': 0.625,
#  'halagador': 0.688,
#  'harmonizable': 0.625,
#  'harmónico': 0.625,
#  'helmíntico': 0.625,
#  'hospitalidad': 0.563,
#  'identificable': 0.625,
#  'idílico': 0.688,
#  'igualado': 0.625,
#  'iluminarse': 0.625,
#  'ilustrado': 0.542,
#  'ilustre': 0.708,
#  'imaginativo': 0.625,
#  'imponente': 0.667,
#  'incontaminado': 0.625,
#  'indicado': 0.679,
#  'inferible': 0.625,
#  'informado': 0.594,
#  'ingenioso': 0.531,
#  'instruido': 0.542,
#  'intelectual': 0.594,
#  'inteligente': 0.604,
#  'interesante': 0.563,
#  'interesarse': 0.563,
#  'interpretable': 0.625,
#  'inventivo': 0.625,
#  'invicto': 0.625,
#  'iterativo': 0.563,
#  'juguetón': 0.563,
#  'justificable': 0.625,
#  'ladino': 0.625,
#  'leal': 0.7,
#  'letrado': 0.563,
#  'lisonjero': 0.688,
#  'lógico': 0.625,
#  'majestuoso': 0.719,
#  'manejable': 0.625,
#  'maravilloso': 0.719,
#  'medicinal': 0.625,
#  'mejor': 0.375,
#  'merecido': 0.625,
#  'mesurado': 0.542,
#  'miramiento': 0.688,
#  'mitigable': 0.625,
#  'moralizador': 0.625,
#  'máximo': 0.625,
#  'noble': 0.542,
#  'nutritivo': 0.688,
#  'obediente': 0.542,
#  'observable': 0.625,
#  'observancia': 0.625,
#  'ocurrente': 0.625,
#  'operable': 0.625,
#  'oportuno': 0.542,
#  'opulento': 0.625,
#  'parasiticida': 0.625,
#  'pasable': 0.542,
#  'patente': 0.542,
#  'pausado': 0.625,
#  'perfectibilidad': 0.625,
#  'perfecto': 0.625,
#  'perseverante': 0.563,
#  'pertinente': 0.563,
#  'pinchable': 0.625,
#  'plenario': 0.625,
#  'pletórico': 0.625,
#  'popularidad': 0.625,
#  'practicable': 0.625,
#  'precaución': 0.583,
#  'precioso': 0.675,
#  'preciso': 0.641,
#  'precocinado': 0.625,
#  'preferible': 0.625,
#  'preparado': 0.531,
#  'preponderante': 0.625,
#  'presciente': 0.625,
#  'preservable': 0.625,
#  'prestigioso': 0.688,
#  'previsor': 0.542,
#  'privilegiado': 0.688,
#  'probado': 0.542,
#  'procedencia': 0.688,
#  'productivo': 0.521,
#  'productor': 0.625,
#  'profiláctico': 0.542,
#  'progresar': 0.688,
#  'prolífero': 0.563,
#  'prolífico': 0.563,
#  'promover': 0.583,
#  'propiciador': 0.625,
#  'propicio': 0.563,
#  'proteccionista': 0.625,
#  'prudente': 0.578,
#  'práctico': 0.521,
#  'próspero': 0.7,
#  'purificado': 0.563,
#  'querido': 0.625,
#  'racional': 0.604,
#  'razonable': 0.625,
#  'reciclable': 0.625,
#  'reconciliador': 0.625,
#  'reconstituyente': 0.563,
#  'recuperativo': 0.625,
#  'rehabilitador': 0.688,
#  'reiterativo': 0.563,
#  'remedio': 0.625,
#  'remirado': 0.625,
#  'rentable': 0.625,
#  'repetible': 0.625,
#  'respetuoso': 0.625,
#  'retozón': 0.625,
#  'retribuido': 0.625,
#  'reverendo': 0.625,
#  'reverente': 0.688,
#  'revivificar': 0.688,
#  'sabio': 0.625,
#  'sagaz': 0.534,
#  'salvador': 0.625,
#  'santificado': 0.625,
#  'santo': 0.25,
#  'selecto': 0.6,
#  'semiconductor': 0.625,
#  'sensato': 0.571,
#  'sentido': 0.625,
#  'seriocómico': 0.625,
#  'servible': 0.542,
#  'sexi': 0.625,
#  'sibarítico': 0.625,
#  'significante': 0.542,
#  'significativo': 0.542,
#  'simplificado': 0.625,
#  'sincero': 0.7,
#  'sobreabundante': 0.625,
#  'socarrón': 0.625,
#  'sociable': 0.542,
#  'soportador': 0.625,
#  'sostenible': 0.563,
#  'suficiente': 0.563,
#  'superabundante': 0.625,
#  'sustancioso': 0.542,
#  'súper': 0.688,
#  'terapéutico': 0.313,
#  'testeado': 0.625,
#  'tibio': 0.625,
#  'tolerable': 0.625,
#  'torneado': 0.688,
#  'tratable': 0.521,
#  'triumfar': 0.625,
#  'valioso': 0.688,
#  'vencedor': 0.625,
#  'venerado': 0.563,
#  'veraz': 0.563,
#  'viable': 0.563,
#  'victoria': 0.625,
#  'vitalizante': 0.625,
#  'vivificante': 0.625,
#  'vocálico': 0.625,
#  'voluptuoso': 0.583,
#  'ético': 0.625,
#  'absorto': 0.5,
#  'abundoso': 0.5,
#  'acaudalado': 0.5,
#  'acelerado': 0.5,
#  'aceptador': 0.5,
#  'acicalado': 0.5,
#  'aclamación': 0.5,
#  'acomodaticio': 0.5,
#  'aconsejado': 0.5,
#  'actualizado': 0.5,
#  'adaptado': 0.5,
#  'adecuación': 0.5,
#  'adinerado': 0.375,
#  'admisibilidad': 0.5,
#  'admisivo': 0.5,
#  'adorable': 0.5,
#  'adorado': 0.5,
#  'adrenocorticotrópico': 0.5,
#  'ahorrador': 0.5,
#  'ahorrativo': 0.5,
#  'airosidad': 0.5,
#  'ajustable': 0.5,
#  'alabanza': 0.5,
#  'aligerar': 0.5,
#  'alquilable': 0.5,
#  'altilocuente': 0.5,
#  'amado': 0.5,
#  'amalgamado': 0.5,
#  'ambidiestro': 0.375,
#  'ameliorar': 0.5,
#  'amentífero': 0.5,
#  'amovible': 0.5,
#  'anacorítico': 0.5,
#  'antimonopolio': 0.5,
#  'antiséptico': 0.5,
#  'apaciguador': 0.5,
#  'apareado': 0.5,
#  'apasionante': 0.5,
#  'aplanético': 0.5,
#  'aplicable': 0.5,
#  'aplicado': 0.5,
#  'apodíctico': 0.5,
#  'apoyado': 0.5,
#  'aprendido': 0.5,
#  'arable': 0.5,
#  'ascendible': 0.5,
#  'asociable': 0.5,
#  'aséptico': 0.5,
#  'autosuficiente': 0.5,
#  'averiguable': 0.5,
#  'aviejarse': 0.5,
#  'avivado': 0.5,
#  'bastante': 0.5,
#  'beatificado': 0.5,
#  'beatífico': 0.5,
#  'bebido': 0.5,
#  'bienintencionado': 0.5,
#  'bordeado': 0.5,
#  'bromista': 0.5,
#  'cadencioso': 0.5,
#  'cadente': 0.5,
#  'cantable': 0.5,
#  'característico': 0.5,
#  'caritativo': 0.5,
#  'casadero': 0.5,
#  'centralizador': 0.5,
#  'civilidad': 0.5,
#  'colmado': 0.5,
#  'combustible': 0.5,
#  'comedia': 0.5,
#  'compatiblemente': 0.5,
#  'comprimible': 0.5,
#  'comprobable': 0.5,
#  'concienciable': 0.5,
#  'conciliador': 0.5,
#  'condicionado': 0.5,
#  'conductivo': 0.5,
#  'conductor': 0.5,
#  'conformar': 0.5,
#  'constitucional': 0.5,
#  'constructividad': 0.5,
#  'consumado': 0.5,
#  'consumar': 0.5,
#  'contestable': 0.5,
#  'copetudo': 0.5,
#  'correctitud': 0.5,
#  'cultivable': 0.5,
#  'curable': 0.5,
#  'cursi': 0.5,
#  'dadivoso': 0.5,
#  'definible': 0.5,
#  'delectable': 0.5,
#  'desafectado': 0.5,
#  'desambiguedad': 0.5,
#  'descansado': 0.5,
#  'desconfiadamente': 0.5,
#  'descubrible': 0.5,
#  'desegregación': 0.5,
#  'desencantar': 0.5,
#  'desgravable': 0.5,
#  'desinflación': 0.5,
#  'desmontable': 0.5,
#  'despavilado': 0.5,
#  'despejado': 0.5,
#  'determinable': 0.5,
#  'diagnosticable': 0.5,
#  'digestibilidad': 0.5,
#  'digestible': 0.5,
#  'discernible': 0.5,
#  'disciplinal': 0.5,
#  'diserto': 0.5,
#  'disputable': 0.5,
#  'distinguible': 0.5,
#  'dorado': 0.5,
#  'dúctil': 0.5,
#  'ecléctico': 0.25,
#  'elocuente': 0.5,
#  'emancipador': 0.5,
#  'embergadura': 0.5,
#  'embriagador': 0.5,
#  'emocionante': 0.5,
#  'emplumado': 0.5,
#  'empático': 0.5,
#  'encadenado': 0.5,
#  'energizante': 0.5,
#  'energético': 0.5,
#  'enfundado': 0.5,
#  'enjoyado': 0.5,
#  'ennoblecedor': 0.5,
#  'envainado': 0.5,
#  'envejecerse': 0.5,
#  'epicúreo': 0.375,
#  'epigramático': 0.5,
#  'eremitíco': 0.5,
#  'escogido': 0.375,
#  'esmaltado': 0.5,
#  'espaldarazo': 0.5,
#  'espavilado': 0.5,
#  'especialización': 0.5,
#  'espiritualidad': 0.5,
#  'estabilidad': 0.5,
#  'estabilizador': 0.5,
#  'estudioso': 0.5,
#  'estético': 0.5,
#  'eufonía': 0.5,
#  'eufónico': 0.5,
#  'eugenesia': 0.5,
#  'eugenismo': 0.5,
#  'evidencial': 0.5,
#  'evitable': 0.5,
#  'exhaustivo': 0.5,
#  'exhausto': 0.5,
#  'exhortatorio': 0.5,
#  'exotérico': 0.5,
#  'expeditivo': 0.5,
#  'explicitación': 0.5,
#  'explicitud': 0.5,
#  'extensísimo': 0.5,
#  'extenuado': 0.5,
#  'fama': 0.5,
#  'fascinado': 0.5,
#  'fascinador': 0.5,
#  'fatigado': 0.5,
#  'fertilidad': 0.5,
#  'festejo': 0.5,
#  'fiducial': 0.5,
#  'filmable': 0.5,
#  'fisionable': 0.5,
#  'flexionado': 0.5,
#  'focalizado': 0.5,
#  'forrado': 0.5,
#  'fortalecedor': 0.5,
#  'galanteo': 0.5,
#  'ganancioso': 0.5,
#  'gazmoño': 0.25,
#  'germinal': 0.5,
#  'gozo': 0.5,
#  'graciosidad': 0.5,
#  'grandiosidad': 0.5,
#  'halagar': 0.5,
#  'higiénico': 0.5,
#  'hipertónico': 0.313,
#  'hipnotizado': 0.5,
#  'histriónico': 0.5,
#  'homeopatía': 0.5,
#  'honores': 0.5,
#  'immaculado': 0.5,
#  'impresionable': 0.5,
#  'impudente': 0.5,
#  'incambiable': 0.5,
#  'incitante': 0.5,
#  'inclusivo': 0.5,
#  'incorrupción': 0.5,
#  'indisimulado': 0.5,
#  'influenciable': 0.5,
#  'innovador': 0.5,
#  'insolvente': 0.5,
#  'intachable': 0.5,
#  'intencional': 0.5,
#  'invalorable': 0.5,
#  'jocoso': 0.5,
#  'justiciable': 0.5,
#  'labrantío': 0.5,
#  'laureado': 0.5,
#  'laurear': 0.5,
#  'laureles': 0.5,
#  'lavorable': 0.5,
#  'legalidad': 0.5,
#  'leído': 0.5,
#  'liberador': 0.25,
#  'limitador': 0.5,
#  'liricidad': 0.5,
#  'loar': 0.5,
#  'lustroso': 0.5,
#  'macro': 0.5,
#  'madurado': 0.5,
#  'magnánime': 0.5,
#  'maniatado': 0.5,
#  'maniobrable': 0.5,
#  'marinería': 0.5,
#  'medicamentoso': 0.5,
#  'meditado': 0.5,
#  'melodioso': 0.5,
#  'mezclable': 0.5,
#  'miopía': 0.5,
#  'miramento': 0.5,
#  'mismísimo': 0.5,
#  'modernizado': 0.5,
#  'mojigato': 0.375,
#  'moldeable': 0.5,
#  'moralmente': 0.5,
#  'nato': 0.5,
#  'neutralizado': 0.5,
#  'novel': 0.5,
#  'nutrido': 0.5,
#  'náutica': 0.5,
#  'núbil': 0.5,
#  'orientarse': 0.5,
#  'ortotropo': 0.5,
#  'ovacionar': 0.5,
#  'panorámico': 0.5,
#  'participativo': 0.5,
#  'patricio': 0.5,
#  'patriótico': 0.5,
#  'payaso': 0.5,
#  'perfeccionado': 0.5,
#  'permisividad': 0.5,
#  'permutable': 0.5,
#  'persuasión': 0.5,
#  'petulante': 0.5,
#  'piadoso': 0.5,
#  'pintoresco': 0.5,
#  'plegable': 0.5,
#  'pormenorizado': 0.5,
#  'pornográfico': 0.5,
#  'precavido': 0.5,
#  'preciosura': 0.5,
#  'preeminente': 0.5,
#  'premiar': 0.5,
#  'preservado': 0.5,
#  'prevención': 0.5,
#  'profundizable': 0.5,
#  'profuso': 0.5,
#  'prometido': 0.5,
#  'propiciación': 0.5,
#  'propiciatoriedad': 0.5,
#  'protagonismo': 0.5,
#  'prudencial': 0.5,
#  'pudiente': 0.5,
#  'puntería': 0.5,
#  'pío': 0.5,
#  'racionalidad': 0.5,
#  'rastrero': 0.5,
#  'ratificar': 0.5,
#  'realizable': 0.5,
#  'reanimado': 0.5,
#  'recio': 0.5,
#  'reconciliable': 0.5,
#  'rectificable': 0.5,
#  'rectitud': 0.5,
#  'recubierto': 0.5,
#  'recuperable': 0.5,
#  'refinar': 0.5,
#  'reflectante': 0.5,
#  'reformatorio': 0.25,
#  'refrendada': 0.5,
#  'refrescante': 0.5,
#  'regente': 0.5,
#  'regulable': 0.5,
#  'rendido': 0.5,
#  'rentabilidad': 0.5,
#  'reparable': 0.5,
#  'replegable': 0.5,
#  'reponerse': 0.5,
#  'representable': 0.5,
#  'representante': 0.5,
#  'resoluble': 0.5,
#  'respaldado': 0.5,
#  'respingón': 0.5,
#  'resplandeciente': 0.5,
#  'retenido': 0.5,
#  'revalidar': 0.5,
#  'revelador': 0.5,
#  'revitalizado': 0.5,
#  'rosáceo': 0.5,
#  'rumboso': 0.5,
#  'sacrosanto': 0.5,
#  'savoir-faire': 0.5,
#  'seleccionado': 0.5,
#  'selectivo': 0.5,
#  'semiprecioso': 0.5,
#  'seráfico': 0.5,
#  'sexuado': 0.5,
#  'sinvergüenza': 0.5,
#  'solvencia': 0.5,
#  'solvente': 0.5,
#  'sublimado': 0.5,
#  'subsanable': 0.5,
#  'subsistir': 0.5,
#  'suertero': 0.5,
#  'sujetable': 0.5,
#  'sumergible': 0.5,
#  'sumo': 0.5,
#  'super': 0.25,
#  'superno': 0.5,
#  'sustancialidad': 0.5,
#  'sómatico': 0.5,
#  'tapizado': 0.5,
#  'taraceado': 0.5,
#  'tasable': 0.5,
#  'templado': 0.5,
#  'tentador': 0.5,
#  'tonicidad': 0.5,
#  'tonificado': 0.5,
#  'transitivo': 0.5,
#  'transplantable': 0.5,
#  ...}

# %%
pos_dict['acertado']
# Out:
# 0.708

# %%
neg_dict = {}
for row in neg_lex.collect():
      neg_dict[row.word] = float(row.puntuacion)
neg_dict
# Out:
# {'abatir': -0.554,
#  'abochornado': -0.25,
#  'abochornar': -0.5,
#  'abominación': -0.425,
#  'aborrecer': -0.625,
#  'aborrecimiento': -0.425,
#  'acongojarse': -0.687,
#  'acosar': -0.304,
#  'aflicción': -0.606,
#  'afligido': -0.396,
#  'afligir': -0.675,
#  'afligirse': -0.687,
#  'agravar': -0.281,
#  'agresividad': -0.35,
#  'alarmar': -0.25,
#  'alboroto': -0.25,
#  'amargura': -0.5,
#  'angustia': -0.589,
#  'angustiado': -0.65,
#  'antipatía': -0.542,
#  'antipático': -0.333,
#  'apesadumbrado': -0.5,
#  'apocamiento': -0.406,
#  'apurarse': -0.35,
#  'arrepentido': -0.5,
#  'arriesgado': -0.25,
#  'asco': -0.357,
#  'asquear': -0.437,
#  'asqueroso': -0.575,
#  'atormentar': -0.391,
#  'atroz': -0.672,
#  'avergonzado': -0.25,
#  'avergonzar': -0.375,
#  'aversión': -0.359,
#  'cabreado': -0.75,
#  'celoso': -0.25,
#  'colérico': -0.458,
#  'confundir': -0.333,
#  'congoja': -0.75,
#  'conmoción': -0.354,
#  'consternado': -0.375,
#  'contrariedad': -0.656,
#  'contrito': -0.5,
#  'crueldad': -0.525,
#  'culpabilidad': -1.0,
#  'culpable': -0.312,
#  'dañino': -0.437,
#  'decaído': -0.375,
#  'defectuoso': -0.431,
#  'degradante': -0.375,
#  'deplorar': -0.406,
#  'deprimente': -1.0,
#  'deprimir': -0.687,
#  'desagradable': -0.65,
#  'desagradar': -0.625,
#  'desagrado': -0.667,
#  'desalentador': -0.333,
#  'desalentar': -0.589,
#  'desaliento': -0.325,
#  'desamparo': -0.275,
#  'desaprobar': -0.292,
#  'desasosiego': -0.344,
#  'desconsolado': -0.875,
#  'descuido': -0.281,
#  'desdicha': -0.547,
#  'desdichado': -0.35,
#  'desdén': -0.363,
#  'desesperado': -0.625,
#  'deshonroso': -0.3,
#  'desolado': -0.562,
#  'despreciable': -0.406,
#  'despreciar': -0.396,
#  'desprecio': -0.406,
#  'desánimo': -0.312,
#  'detestar': -0.667,
#  'devastador': -0.45,
#  'difícil': -0.667,
#  'disgustado': -0.437,
#  'disgustar': -0.5,
#  'disuadir': -0.25,
#  'dolor': -0.488,
#  'dolorido': -0.719,
#  'doloroso': -0.625,
#  'encolerizar': -0.437,
#  'enemistad': -0.281,
#  'enfadado': -0.625,
#  'enfadar': -0.25,
#  'enfurecer': -0.375,
#  'enojado': -0.5,
#  'enojar': -0.437,
#  'enojoso': -0.875,
#  'entristecer': -0.375,
#  'escalofriante': -0.333,
#  'espantar': -0.286,
#  'espantoso': -0.643,
#  'exacerbación': -0.375,
#  'exasperar': -0.525,
#  'fastidiar': -0.359,
#  'fastidioso': -0.75,
#  'fatal': -0.275,
#  'frustrado': -0.5,
#  'frío': -0.292,
#  'furia': -0.4,
#  'furioso': -0.3,
#  'harto': -0.25,
#  'hastío': -0.281,
#  'herir': -0.458,
#  'histeria': -0.437,
#  'horrible': -0.429,
#  'horripilante': -0.4,
#  'horror': -0.354,
#  'horrorizar': -0.437,
#  'horroroso': -0.5,
#  'hostigar': -0.35,
#  'hostilidad': -0.344,
#  'humillar': -0.458,
#  'impaciencia': -0.333,
#  'impotencia': -0.25,
#  'inadecuado': -0.288,
#  'inclemente': -0.25,
#  'incomodar': -0.425,
#  'incómodo': -0.271,
#  'inoportuno': -0.361,
#  'inquietante': -0.375,
#  'inquieto': -0.275,
#  'inquina': -0.25,
#  'insatisfecho': -0.5,
#  'inseguridad': -0.437,
#  'insuficiente': -0.375,
#  'intolerable': -0.25,
#  'iracundo': -0.583,
#  'irascible': -0.562,
#  'irritación': -0.417,
#  'irritante': -0.5,
#  'irritar': -0.361,
#  'lamentable': -0.4,
#  'malhumor': -0.531,
#  'malicia': -0.375,
#  'maligno': -0.469,
#  'malévolo': -0.775,
#  'melancolía': -0.375,
#  'melancólico': -0.25,
#  'menospreciar': -0.268,
#  'menosprecio': -0.304,
#  'miedoso': -0.25,
#  'miserable': -0.3,
#  'misoneísmo': -0.25,
#  'mohína': -0.312,
#  'molestar': -0.458,
#  'molesto': -0.538,
#  'monstruoso': -0.396,
#  'mosqueado': -0.75,
#  'nauseabundo': -0.25,
#  'negro': -0.25,
#  'nocivo': -0.437,
#  'odiar': -1.0,
#  'odio': -0.5,
#  'ofender': -0.594,
#  'ofensivo': -0.429,
#  'opresión': -0.375,
#  'oscuro': -0.575,
#  'pavor': -0.437,
#  'pena': -0.458,
#  'penoso': -0.321,
#  'perjudicial': -0.455,
#  'perturbar': -0.406,
#  'pesadumbre': -0.575,
#  'pesar': -0.562,
#  'pesaroso': -0.437,
#  'pesimismo': -0.333,
#  'pesimista': -0.375,
#  'problema': -0.437,
#  'pánico': -0.292,
#  'quemazón': -0.281,
#  'rabia': -0.271,
#  'recelo': -0.25,
#  'rechazar': -0.26,
#  'rencor': -0.542,
#  'repelo': -0.312,
#  'repugnancia': -0.406,
#  'repugnante': -0.422,
#  'repulsivo': -0.25,
#  'resentimiento': -0.594,
#  'sombrío': -0.5,
#  'temer': -0.583,
#  'temeroso': -0.375,
#  'temible': -0.417,
#  'terrible': -0.562,
#  'tormento': -0.482,
#  'trastorno': -0.375,
#  'tribulación': -0.281,
#  'triste': -0.509,
#  'tristeza': -0.45,
#  'vergüenza': -0.375,
#  'vilipendio': -0.917,
#  'abatido': -0.312,
#  'abatimiento': -0.375,
#  'abominar': -0.375,
#  'aborrecible': -0.25,
#  'acoso': -0.5,
#  'agravado': -0.375,
#  'airado': -0.5,
#  'alarmado': -0.25,
#  'alterado': -0.375,
#  'angustiosamente': -0.75,
#  'animadversión': -0.5,
#  'ansiosamente': -0.5,
#  'apenado': -0.458,
#  'apenar': -0.281,
#  'apenarse': -0.875,
#  'apocar': -0.687,
#  'aprensivo': -0.25,
#  'aprensión': -0.312,
#  'arrepentimiento': -0.375,
#  'asediar': -0.25,
#  'asqueadamente': -0.5,
#  'asqueado': -0.25,
#  'asurarse': -0.375,
#  'aterrorizado': -0.25,
#  'autocompasión': -0.25,
#  'avaricioso': -0.583,
#  'avaro': -0.5,
#  'avergonzante': -0.5,
#  'avergonzarse': -0.25,
#  'basca': -0.25,
#  'beligerancia': -0.312,
#  'beligerante': -0.458,
#  'berrinche': -0.625,
#  'calamitoso': -0.5,
#  'cargante': -0.562,
#  'celos': -0.25,
#  'celosamente': -0.25,
#  'codiciar': -0.5,
#  'coléricamente': -0.75,
#  'compadecer': -0.625,
#  'compadecerse': -0.75,
#  'compunción': -0.625,
#  'concomerse': -0.25,
#  'conmiseración': -0.375,
#  'consternación': -0.375,
#  'consternar': -0.344,
#  'contrariado': -0.375,
#  'contrición': -0.25,
#  'conturbar': -0.25,
#  'corazonada': -0.25,
#  'cuita': -0.312,
#  'cínico': -0.667,
#  'decepcionante': -0.375,
#  'deficiente': -0.25,
#  'defraudado': -0.5,
#  'demolidor': -0.375,
#  'depre': -0.625,
#  'deprimido': -0.5,
#  'desacreditado': -0.375,
#  'desagradablemente': -0.375,
#  'desagradecimiento': -1.0,
#  'desanimar': -0.687,
#  'desasosegadamente': -0.5,
#  'desasosegado': -0.562,
#  'desazón': -0.25,
#  'descompostura': -0.25,
#  'desconsuelo': -0.75,
#  'desdeñar': -1.0,
#  'desecho': -0.5,
#  'desesperadamente': -0.5,
#  'desesperanzado': -0.5,
#  'desfallecimiento': -0.5,
#  'desgarrador': -0.333,
#  'deshonrado': -0.75,
#  'desmoralizador': -0.312,
#  'desmoralizar': -0.375,
#  'despavorido': -0.25,
#  'despecho': -0.375,
#  'destructivo': -0.583,
#  'detestación': -0.625,
#  'dificultoso': -0.25,
#  'disforia': -0.75,
#  'disgustoso': -0.75,
#  'dolido': -0.625,
#  'dolorosamente': -0.375,
#  'embarazoso': -0.5,
#  'encolerizarse': -0.625,
#  'encono': -0.375,
#  'enfadarse': -0.75,
#  'enfadoso': -1.0,
#  'enfurecerse': -0.5,
#  'enfurecido': -0.5,
#  'enfurecimiento': -0.25,
#  'enfurruñarse': -0.375,
#  'engorroso': -0.75,
#  'enloquecido': -0.75,
#  'enojarse': -0.75,
#  'enojo': -0.333,
#  'entristecerse': -0.708,
#  'entristecido': -0.5,
#  'espantado': -0.25,
#  'estremecedor': -0.562,
#  'exacerbar': -0.437,
#  'exasperación': -0.312,
#  'exasperante': -0.312,
#  'execración': -0.417,
#  'execrar': -0.375,
#  'fastidiado': -0.75,
#  'frenéticamente': -0.25,
#  'frustrante': -0.5,
#  'furibundo': -0.5,
#  'furiosamente': -0.437,
#  'grima': -0.25,
#  'hormiguilla': -0.375,
#  'horrendo': -0.625,
#  'horrorizado': -0.625,
#  'humillante': -0.75,
#  'ignominioso': -0.5,
#  'impropio': -0.375,
#  'indignado': -0.5,
#  'indignante': -0.5,
#  'ingratitud': -1.0,
#  'inhumanidad': -0.333,
#  'inmundo': -0.312,
#  'inquietarse': -0.333,
#  'insidia': -0.437,
#  'intimidado': -0.292,
#  'iracundia': -0.375,
#  'irascibilidad': -0.375,
#  'irritado': -0.625,
#  'lastimero': -0.75,
#  'lóbregamente': -0.375,
#  'lóbrego': -0.812,
#  'lúgubre': -0.5,
#  'lúgubremente': -0.375,
#  'macabro': -0.75,
#  'maleficencia': -0.562,
#  'malevolencia': -0.562,
#  'malignidad': -0.562,
#  'malquerencia': -0.375,
#  'maléfico': -0.875,
#  'misantropía': -0.437,
#  'misantrópico': -1.0,
#  'misoginia': -0.625,
#  'misántropo': -0.75,
#  'misógino': -0.687,
#  'mohíno': -0.75,
#  'mortificado': -0.25,
#  'mortificante': -0.5,
#  'mortificar': -0.562,
#  'murria': -0.375,
#  'mísero': -0.25,
#  'nauseoso': -0.25,
#  'oprobioso': -0.5,
#  'pataleta': -0.625,
#  'pavoroso': -0.75,
#  'perra': -0.25,
#  'perturbador': -0.625,
#  'petrificado': -0.25,
#  'picado': -0.333,
#  'preocupado': -0.292,
#  'provocado': -0.75,
#  'quejumbroso': -0.625,
#  'rabieta': -0.625,
#  'rabioso': -0.292,
#  'reconcomerse': -0.25,
#  'remordimiento': -0.333,
#  'repugnar': -0.375,
#  'repulsión': -0.458,
#  'resentido': -0.458,
#  'resignarse': -0.25,
#  'retraído': -0.375,
#  'sulfurado': -0.312,
#  'terrorífico': -0.625,
#  'transtornado': -0.75,
#  'turbado': -0.5,
#  'ultrajante': -0.5,
#  'vejación': -0.542,
#  'vejar': -0.312,
#  'verecundia': -0.25,
#  'verraquera': -0.625,
#  'adinamia': -0.875,
#  'adulterino': -0.375,
#  'agarrado': -0.875,
#  'amenazador': -1.0,
#  'ampollar': -0.875,
#  'angustiar': -1.0,
#  'antiestético': -1.0,
#  'apestoso': -0.917,
#  'asesino': -0.875,
#  'asimetría': -0.875,
#  'atrofia': -1.0,
#  'autodestructivo': -0.875,
#  'averno': -0.875,
#  'calumniador': -0.25,
#  'calumnioso': -1.0,
#  'censurable': -0.917,
#  'cerrilismo': -0.875,
#  'ceño': -0.875,
#  'cicatero': -1.0,
#  'condenable': -1.0,
#  'condenatorio': -1.0,
#  'condolencia': -0.875,
#  'condolencias': -0.875,
#  'contrabandista': -1.0,
#  'criticable': -1.0,
#  'denigrador': -1.0,
#  'denigratorio': -1.0,
#  'desacreditador': -1.0,
#  'desamparar': -1.0,
#  'desaprovechamiento': -1.0,
#  'desarmonía': -0.875,
#  'desasistir': -1.0,
#  'desconocer': -1.0,
#  'descorazonar': -1.0,
#  'desequilibrio': -0.812,
#  'desesperanzar': -1.0,
#  'desgraciados': -1.0,
#  'deshonor': -0.875,
#  'desprestigiador': -1.0,
#  'desventajoso': -0.875,
#  'deteriorable': -0.875,
#  'difamador': -1.0,
#  'difamatorio': -1.0,
#  'disconformidad': -0.875,
#  'discontinuidad': -0.875,
#  'disimulador': -1.0,
#  'envilecimiento': -0.875,
#  'escrofuloso': -1.0,
#  'espurio': -1.0,
#  'excoriación': -0.875,
#  'expensas': -1.0,
#  'falsario': -1.0,
#  'fechoría': -1.0,
#  'feo': -0.833,
#  'fingir': -0.792,
#  'frunción': -0.875,
#  'fríamente': -0.875,
#  'fétido': -0.875,
#  'fóbico': -1.0,
#  'garrapo': -1.0,
#  'guindar': -0.875,
#  'hipocondríaco': -0.375,
#  'homicida': -1.0,
#  'huraño': -0.792,
#  'impasable': -1.0,
#  'impersonalmente': -1.0,
#  'inanidad': -0.875,
#  'incompetencia': -0.844,
#  'inconstructivo': -1.0,
#  'incriminable': -1.0,
#  'incultura': -0.875,
#  'indigestible': -0.875,
#  'ineficacia': -0.812,
#  'ineficiencia': -0.875,
#  'inelasticidad': -0.875,
#  'ineligible': -0.875,
#  'infierno': -0.8,
#  'infranqueable': -0.937,
#  'inhabilidad': -0.875,
#  'injurioso': -1.0,
#  'inobservancia': -0.812,
#  'insubstancialidad': -0.875,
#  'intransitable': -1.0,
#  'irrepresentable': -0.875,
#  'kitsch': -0.375,
#  'lagrimar': -0.875,
#  'lerdo': -0.812,
#  'malhumorado': -0.833,
#  'maloliente': -1.0,
#  'maniacodepresivo': -0.5,
#  'matutero': -1.0,
#  'mentiroso': -0.25,
#  'metedor': -1.0,
#  'noluntad': -1.0,
#  'orco': -0.875,
#  'padecimiento': -1.0,
#  'parásitos': -0.875,
#  'pestilente': -1.0,
#  'pillado': -0.875,
#  'protestatario': -1.0,
#  'protestativo': -1.0,
#  'psicopatológico': -0.875,
#  'psicopático': -0.875,
#  'putada': -0.875,
#  'putería': -1.0,
#  'putrescible': -0.875,
#  'pésame': -0.875,
#  'ramplonería': -0.875,
#  'rata': -0.875,
#  'recriminable': -1.0,
#  'regañón': -1.0,
#  'reprensible': -1.0,
#  'reprochable': -1.0,
#  'roncería': -1.0,
#  'saqueado': -0.875,
#  'suicida': -0.875,
#  'tacaño': -0.875,
#  'tenebroso': -1.0,
#  'tontamente': -0.875,
#  'torcedor': -1.0,
#  'veleidoso': -1.0,
#  'abúlico': -0.75,
#  'acongojado': -0.75,
#  'agonizar': -0.75,
#  'agónico': -0.75,
#  'ahuecamiento': -0.75,
#  'algofóbico': -0.75,
#  'amencia': -0.75,
#  'antipatriótico': -0.75,
#  'aparatosidad': -0.75,
#  'autoincriminación': -0.75,
#  'autoinculpación': -0.75,
#  'autotormento': -0.75,
#  'autotortura': -0.75,
#  'aventurado': -0.75,
#  'bastedad': -0.75,
#  'bilioso': -0.75,
#  'burlón': -0.75,
#  'canallada': -0.75,
#  'canallesco': -0.75,
#  'caradura': -0.75,
#  'carcomido': -0.75,
#  'ceguedad': -0.75,
#  'ceguera': -0.75,
#  'ceñudo': -0.75,
#  'contumelia': -0.75,
#  'cretino': -0.75,
#  'culpa': -0.75,
#  'degradarse': -0.75,
#  'denunciable': -0.75,
#  'desafortunadamente': -0.75,
#  'desesclarecedor': -0.75,
#  'deshonrarse': -0.75,
#  'deshonrosamente': -0.75,
#  'despreciado': -0.75,
#  'destructividad': -0.75,
#  'desvancerse': -0.75,
#  'detestado': -0.75,
#  'dispéptico': -0.75,
#  'encontrón': -0.75,
#  'engravecer': -0.75,
#  'envanecimiento': -0.75,
#  'espúreo': -0.75,
#  'esquizofrénico': -0.25,
#  'fraudulento': -0.75,
#  'gafe': -0.75,
#  'golpiza': -0.75,
#  'hedor': -0.75,
#  'hipocondría': -0.75,
#  'hosco': -0.75,
#  'idiota': -0.75,
#  'imperfectamente': -0.75,
#  'impetuoso': -0.75,
#  'impopularidad': -0.75,
#  'imprevisión': -0.75,
#  'imprevisor': -0.75,
#  'impropicio': -0.75,
#  'inamovible': -0.75,
#  'incombinable': -0.75,
#  'inconsolable': -0.75,
#  'indigerible': -0.75,
#  'indigno': -0.75,
#  'ineficiente': -0.75,
#  'inexpiable': -0.75,
#  'inextricable': -0.75,
#  'infligir': -0.75,
#  'inflingir': -0.75,
#  'ingrato': -0.75,
#  'inhospitalidad': -0.75,
#  'insolvencia': -0.75,
#  'insultante': -0.75,
#  'invidencia': -0.75,
#  'irreversible': -0.75,
#  'linchar': -0.75,
#  'lividez': -0.75,
#  'luto': -0.75,
#  'magnicidio': -0.75,
#  'malparir': -0.75,
#  'mefítico': -0.75,
#  'misofóbico': -0.75,
#  'odiado': -0.75,
#  'paroxismo': -0.75,
#  'pasividad': -0.75,
#  'pestazo': -0.75,
#  'pleito': -0.75,
#  'profanado': -0.75,
#  'regañar': -0.75,
#  'satanofobia': -0.75,
#  'sordera': -0.75,
#  'sucedáneo': -0.75,
#  'testaduro': -0.75,
#  'tramposo': -0.75,
#  'traumatizar': -0.75,
#  'tufillo': -0.75,
#  'tufo': -0.75,
#  'vermiculado': -0.75,
#  'verminoso': -0.75,
#  'xenófobo': -0.75,
#  'ñoño': -0.75,
#  'abetalipoproteinemia': -0.625,
#  'acetoso': -0.562,
#  'acriminación': -0.625,
#  'adulterar': -0.562,
#  'afanar': -0.687,
#  'agobiar': -0.594,
#  'agobio': -0.625,
#  'agonía': -0.625,
#  'agorero': -0.687,
#  'agridulce': -0.562,
#  'altercado': -0.531,
#  'amnésico': -0.625,
#  'amortecerse': -0.625,
#  'anglofobia': -0.625,
#  'apechar': -0.625,
#  'apretura': -0.625,
#  'aprieto': -0.625,
#  'arisco': -0.675,
#  'arrizar': -0.625,
#  'arruinarse': -0.625,
#  'asesinar': -0.625,
#  'asesinato': -0.625,
#  'asolador': -0.625,
#  'atezado': -0.625,
#  'atonía': -0.625,
#  'atrofiarse': -0.625,
#  'aturdimento': -0.625,
#  'avinagrado': -0.562,
#  'bastardo': -0.437,
#  'basto': -0.25,
#  'befar': -0.625,
#  'birlar': -0.542,
#  'brete': -0.625,
#  'bufar': -0.625,
#  'camorrero': -0.625,
#  'cansancio': -0.625,
#  'carente': -0.625,
#  'cargarse': -0.625,
#  'cascarrabias': -0.375,
#  'castigar': -0.562,
#  'censurador': -0.625,
#  'chabacanería': -0.562,
#  'chacoteo': -0.625,
#  'chafarrinón': -0.625,
#  'chaquetero': -0.625,
#  'choquear': -0.625,
#  'combatir': -0.625,
#  'comparendo': -0.625,
#  'conflicto': -0.625,
#  'contrasentido': -0.562,
#  'correría': -0.625,
#  'corrupto': -0.542,
#  'dañoso': -0.531,
#  'defecto': -0.667,
#  'deficiencia': -0.575,
#  'delito': -0.687,
#  'desaconsejado': -0.562,
#  'desagradecido': -0.625,
#  'desasimiento': -0.625,
#  'desasistido': -0.625,
#  'desautorizar': -0.625,
#  'descalificado': -0.625,
#  'descaramiento': -0.625,
#  'descortesía': -0.521,
#  'descortés': -0.525,
#  'desenmadejar': -0.625,
#  'desfavorable': -0.594,
#  'deshonra': -0.719,
#  'deshonrar': -0.708,
#  'desigualmente': -0.625,
#  'deslucimiento': -0.562,
#  'desobedecer': -0.625,
#  'desproporcionado': -0.667,
#  'destructor': -0.687,
#  'destruirse': -0.625,
#  'desértico': -0.562,
#  'detrimento': -0.625,
#  'discordia': -0.542,
#  'dismenorrea': -0.625,
#  'disturbar': -0.687,
#  'divisivo': -0.625,
#  'doler': -0.525,
#  'dramón': -0.625,
#  'elegía': -0.625,
#  'embabucar': -0.625,
#  'embaucar': -0.594,
#  'embaír': -0.625,
#  'emboscada': -0.625,
#  'encandilar': -0.625,
#  'endiablado': -0.625,
#  'engañosamente': -0.625,
#  'engreimiento': -0.562,
#  'enterrado': -0.625,
#  'eritrodermia': -0.625,
#  'escapatoria': -0.625,
#  'escocedura': -0.625,
#  'escozor': -0.625,
#  'estrago': -0.625,
#  'estática': -0.625,
#  'faccioso': -0.625,
#  'falazmente': -0.625,
#  'falsificar': -0.521,
#  'farfolla': -0.625,
#  'filfa': -0.625,
#  'fracasar': -0.625,
#  'fullería': -0.625,
#  'fusilar': -0.625,
#  'galbana': -0.625,
#  'garabatos': -0.625,
#  'garrapato': -0.625,
#  'gilipollas': -0.583,
#  'grosero': -0.437,
#  'grosería': -0.589,
#  'hambruna': -0.562,
#  'hediondez': -0.542,
#  'hijoputa': -0.625,
#  'hipognato': -0.625,
#  'hipotiroidismo': -0.625,
#  'holgazanería': -0.625,
#  'hortera': -0.625,
#  'hosquedad': -0.562,
#  'hurtar': -0.687,
#  'ido': -0.625,
#  'ignorancia': -0.562,
#  'ignorante': -0.25,
#  'ilógico': -0.25,
#  'imaginado': -0.625,
#  'imaginario': -0.625,
#  'impensable': -0.625,
#  'imperdonable': -0.562,
#  'implacable': -0.625,
#  'imprecación': -0.625,
#  'improperio': -0.542,
#  'impropiedad': -0.625,
#  'impás': -0.625,
#  'inadmisible': -0.625,
#  'inanimado': -0.687,
#  'inapetente': -0.625,
#  'inapetitoso': -0.625,
#  'incognoscible': -0.625,
#  'incomprensión': -0.625,
#  'increpación': -0.562,
#  'increpar': -0.625,
#  'incriminación': -0.625,
#  'inculpación': -0.562,
#  'indecencia': -0.583,
#  'indecoroso': -0.583,
#  'indigesto': -0.687,
#  'inexpugnable': -0.625,
#  'infernal': -0.525,
#  'inhabilitado': -0.625,
#  'inmerecido': -0.7,
#  'inmutabilidad': -0.625,
#  'insensitividad': -0.625,
#  'irreconocible': -0.687,
#  'irrecuperable': -0.625,
#  'irreducible': -0.625,
#  'lasitud': -0.531,
#  'llorar': -0.667,
#  'lordosis': -0.625,
#  'mal': -0.375,
#  'maldición': -0.562,
#  'mandinga': -0.625,
#  'melodramático': -0.625,
#  'mentir': -0.625,
#  'mestizar': -0.625,
#  'mácula': -0.562,
#  'obscuridad': -0.625,
#  'odinofagia': -0.625,
#  'oscurecerse': -0.625,
#  'osteofito': -0.625,
#  'padecer': -0.562,
#  'pajarota': -0.625,
#  'palabrota': -0.625,
#  'paranoico': -0.375,
#  'paraplejia': -0.625,
#  'paraplejía': -0.625,
#  'paraplégico': -0.625,
#  'peleador': -0.625,
#  'peligroso': -0.667,
#  'penalizar': -0.542,
#  'pendenciero': -0.417,
#  'perdida': -0.625,
#  'perdularia': -0.625,
#  'picaresca': -0.625,
#  'pitada': -0.625,
#  'precariedad': -0.562,
#  'principiante': -0.625,
#  'prognato': -0.625,
#  'prohibidor': -0.625,
#  'provincianismo': -0.625,
#  'pusilanimidad': -0.625,
#  'quejido': -0.625,
#  'rachear': -0.625,
#  'rebato': -0.625,
#  'recalcitrar': -0.625,
#  'rechiflar': -0.625,
#  'recular': -0.625,
#  'regañina': -0.562,
#  'regaño': -0.562,
#  'reniego': -0.625,
#  'reprochar': -0.667,
#  'reproche': -0.583,
#  'resentirse': -0.625,
#  'resignacion': -0.625,
#  'roñoso': -0.719,
#  'rudo': -0.575,
#  'ruin': -0.542,
#  'rácano': -0.708,
#  'saltarse': -0.583,
#  'saprófito': -0.25,
#  'silbas': -0.625,
#  'siniestro': -0.25,
#  'socorrer': -0.625,
#  'soez': -0.625,
#  'subdesarrollo': -0.625,
#  'sufrimiento': -0.578,
#  'tiranicidio': -0.625,
#  'tosquedad': -0.625,
#  'traicionar': -0.687,
#  'tísico': -0.625,
#  'vaya': -0.625,
#  'vituperación': -0.625,
#  'volteado': -0.625,
#  'volubilidad': -0.625,
#  'voluble': -0.562,
#  'yerto': -0.625,
#  'zafiedad': -0.667,
#  'zafio': -0.625,
#  'ablandabrevas': -0.5,
#  'abombar': -0.5,
#  'abordabilidad': -0.5,
#  'abroncar': -0.5,
#  'aburrir': -0.5,
#  'abusión': -0.5,
#  'acalorar': -0.5,
#  'aciago': -0.5,
#  'acoquinado': -0.5,
#  'acracia': -0.5,
#  'adiposo': -0.5,
#  'adustez': -0.5,
#  'agentes': -0.5,
#  'agranulocítico': -0.5,
#  'alarmismo': -0.5,
#  'albuminuria': -0.5,
#  'algómetro': -0.5,
#  'alopécico': -0.5,
#  'aminorado': -0.5,
#  'analfabetismo': -0.5,
#  'anarquía': -0.5,
#  'anatematizar': -0.5,
#  'anestesia': -0.5,
#  'anginal': -0.5,
#  'anginoso': -0.5,
#  'angustioso': -0.5,
#  'aniquilación': -0.5,
#  'aniquilamiento': -0.5,
#  'anodino': -0.25,
#  'anquilosis': -0.5,
#  'antagonizar': -0.5,
#  'ante-mortem': -0.5,
#  'apelante': -0.5,
#  'apocalipsis': -0.5,
#  'ardentía': -0.5,
#  'ardores': -0.5,
#  'arrasamiento': -0.5,
#  'arruinamiento': -0.5,
#  'artralgia': -0.5,
#  'asaltante': -0.25,
#  'asolar': -0.5,
#  'astrafobia': -0.5,
#  'astuta': -0.5,
#  'astuto': -0.5,
#  'atacante': -0.5,
#  'aterrador': -0.5,
#  'atolladero': -0.5,
#  'atormentarse': -0.5,
#  'atrasarse': -0.5,
#  'aventar': -0.5,
#  'ay': -0.5,
#  'azarosamente': -0.5,
#  'aztreonam': -0.5,
#  'baldado': -0.5,
#  'batracomiomaquia': -0.5,
#  'befa': -0.5,
#  'bellacamente': -0.5,
#  'berenjenal': -0.5,
#  'beriberi': -0.5,
#  'bibos': -0.5,
#  'biserrado': -0.5,
#  'blanquito': -0.5,
#  'bluff': -0.5,
#  'bragas': -0.5,
#  'broncoespasmo': -0.5,
#  'bronquítico': -0.5,
#  'cabezudo': -0.5,
#  'cabezón': -0.5,
#  'cacofonía': -0.5,
#  'cacofónico': -0.5,
#  'cadaverina': -0.5,
#  'cafre': -0.5,
#  'cagarla': -0.5,
#  'cagón': -0.5,
#  'calambrazo': -0.5,
#  'calambre': -0.5,
#  'calumnia': -0.5,
#  'canotier': -0.5,
#  'canotié': -0.5,
#  'cantonero': -0.5,
#  'cariadura': -0.5,
#  'castigable': -0.5,
#  'cataclísmico': -0.5,
#  'catastrofismo': -0.5,
#  'chapuza': -0.25,
#  'charro': -0.5,
#  'cheposo': -0.5,
#  'chiquilicuatro': -0.5,
#  'chirriante': -0.5,
#  'chismosa': -0.5,
#  'chucho': -0.5,
#  'cizañar': -0.5,
#  'cleptómano': -0.5,
#  'cnidiosporidios': -0.5,
#  'colchoneta': -0.5,
#  'cominero': -0.5,
#  'comisar': -0.5,
#  'complicar': -0.5,
#  'comprometedor': -0.5,
#  'condolerse': -0.5,
#  'confrontar': -0.5,
#  'consolable': -0.5,
#  'contrabandear': -0.5,
#  'contrahacimiento': -0.5,
#  'contrahecho': -0.5,
#  'corcovado': -0.5,
#  'crepuscular': -0.5,
#  'criminalmente': -0.5,
#  'criticón': -0.5,
#  'crédulo': -0.5,
#  'cubil': -0.5,
#  'curco': -0.5,
#  'curioseo': -0.5,
#  'decoloración': -0.5,
#  'deletereo': -0.5,
#  'demente': -0.312,
#  'deprecación': -0.5,
#  'desabrido': -0.5,
#  'desanimadamente': -0.5,
#  'desapacible': -0.5,
#  'desaprensión': -0.5,
#  'desatención': -0.5,
#  'descariñado': -0.5,
#  'descolorido': -0.5,
#  'desdeñable': -0.5,
#  'desenmarañado': -0.5,
#  'desfavorecer': -0.5,
#  'desgraciadamente': -0.5,
#  'deshonestamente': -0.5,
#  'deshonesto': -0.5,
#  'desinclinado': -0.5,
#  'desmejorar': -0.5,
#  'desmesura': -0.5,
#  'desorientamiento': -0.5,
#  'desprotección': -0.5,
#  'desproveído': -0.5,
#  'destructibilidad': -0.5,
#  'dificultad': -0.5,
#  'disimulación': -0.5,
#  'disonancia': -0.5,
#  'disparejo': -0.5,
#  'disuria': -0.5,
#  'elegiaco': -0.5,
#  'embastecido': -0.5,
#  'embravecido': -0.5,
#  'empalidecer': -0.5,
#  'empeorarse': -0.5,
#  'encame': -0.5,
#  'endecha': -0.5,
#  'enemistar': -0.5,
#  'enervado': -0.5,
#  'enfrentamiento': -0.5,
#  'enfrentar': -0.5,
#  'ennegrecer': -0.5,
#  'ennegrecerse': -0.5,
#  'enrarecido': -0.5,
#  'entorpecer': -0.5,
#  'entrometida': -0.5,
#  'entumecido': -0.5,
#  'envilecido': -0.5,
#  'eritema': -0.5,
#  'escarcharse': -0.5,
#  'escarnecedor': -0.5,
#  'esguince': -0.5,
#  'esmerarse': -0.5,
#  'espasmo': -0.5,
#  'especiosidad': -0.5,
#  'espermicida': -0.5,
#  'espondilitis': -0.5,
#  'esporádico': -0.5,
#  'estereotipado': -0.5,
#  'estranguladores': -0.5,
#  'estremecido': -0.5,
#  'estresante': -0.5,
#  'estribación': -0.5,
#  'estúpidamente': -0.5,
#  ...}

# %%
neg_dict['abatir']
# Out:
# -0.554

# %%
# Función para calcular la puntuación por palabra y por fichero base.
def getWordScore(word, base_words):
    puntuacion = 0.0
    if type(word) is str :
        if word in base_words :
            puntuacion = base_words[word]
    return puntuacion

# %%
# Función para calcular puntuación por frase.
def getSentenceScore(sentence):
    puntuacion = 0.0
    if type(sentence) is str :
        for word in sentence.split():
            word_lower = word.lower()
            puntuacion += getWordScore(word_lower, pos_dict)
            puntuacion += getWordScore(word_lower, neg_dict)
    return puntuacion

# %%
getWordScore('abatir', neg_dict)
# Out:
# -0.554

# %%
getWordScore('afición', pos_dict)
# Out:
# 0.5

# %%
getSentenceScore('aBaTir Gabilondo: "Sí. Hay que devolver la tarjeta sanitaria a los inmigrantes" http://t.co/84g2BqqQjU')
# Out:
# -0.554

# %% [markdown]
# ### Creamos una función que devuelva si POSITIVO, NEUTRO o NEGATIVO

# %%
def score2Word(score):
    if score < 0.0: word = 'NEGATIVO'
    elif score > 0.: word = 'POSITIVO'
    else: word = 'NEUTRO'
    return word

# %%
score2Word(0.0)
# Out:
# 'NEUTRO'

# %%
score2Word(0.1)
# Out:
# 'POSITIVO'

# %%
score2Word(-0.1)
# Out:
# 'NEGATIVO'

# %% [markdown]
# ### Por último ejecutamos las funciones por cada mensaje recibido en el topic de kafka e imprimimos

# %%
tweet_score = kafkaStream.map( lambda tweet: (tweet[1], getSentenceScore(tweet[1]))).map(lambda t_p: (t_p[0], t_p[1] , score2Word(t_p[1])))

# %%
tweet_score.pprint()

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2020-01-12 21:28:37
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-01-12 21:28:38
# -------------------------------------------
# ('@Olicaminos en serio me lo contas geniaaa!! :D', 0.0, 'NEUTRO')
# ('"El acuerdo en Cataluña es que aparezca el nombre de Podemos, con un guión y el resto de apoyos" @Pablo_Iglesias_ #PabloIglesiasM4', -0.375, 'NEGATIVO')
# ('@maariisol dejaste de estar en la Friendzone :D', 0.0, 'NEUTRO')
# ('Demostrame que, tu amor vale la pena,asi yo me la juego y empezamos hacer la nuestra.🎶', 0.278, 'POSITIVO')
# ('Resumen de Twitter hoy:.iOS 7.GTA V .iOS 7.iOS 7.GTA V  .iOS 7.GTA V ..Y algún tipo que tuiteo ¡Feliz año 2011! desde Internet Explorer.', 0.0, 'NEUTRO')
# ('"Nunca había visto tanta gente en este colegio como hoy", dice un apoderado en #Madrid Y así en toda España. #PSOE24M http://t.co/OAzsk74sHH', -0.375, 'NEGATIVO')
# ('@apotema69 jo, mierda jajajaja 😂😂😂 Bon dia guapo :) **', 0.75, 'POSITIVO')
# ('Las pilas cargadas rebotan menos que los gastadas: demostración visual #ciencia #gadgets http://t.co/0a6RlBOFez http://t.co/W0sSsiCTBN', 0.0, 'NEUTRO')
# ('Mira Lo Que Ocurre Cuando Este Perro Escucha La Canción “Let It Go” :D - http://t.co/Tvl5OMFqfG', -0.375, 'NEGATIVO')
# ('Rodillo popular. El @GPPopular veta todas las comparecencias solicitadas por el @PSOE http://t.co/hkMsCUjz6I #Congreso', 0.0, 'NEUTRO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:39
# -------------------------------------------
# ('El esfuerzo de los ciudadanos y las reformas del Gobierno han permitido que España camine hacia la recuperación @c_floriano', 0.0, 'NEUTRO')
# ('caro_ad jaja! El tuyo termina con medicación. :P', 0.0, 'NEUTRO')
# ('Las TransferJet SD de Toshiba ofrecen previsualizaciones vía NFC - http://t.co/ELQuEKc0v5 http://t.co/SsxzfqYxZN', 0.0, 'NEUTRO')
# ('SMITE (JUEGO GRATIS): Zeus (Mid): http://t.co/zozQ4yUaQe vía @YouTube', 0.0, 'NEUTRO')
# ('Otro dia mega productivo! Ahora al cine a ver Avengers! 🎬🎥😀', 0.0, 'NEUTRO')
# ('Adoro que la gente se haga completas imágenes mentales de mi personalidad tras cruzar 20 DMs. PD: NO, y dice menos de vosotros que de mi :P', 0.0, 'NEUTRO')
# ('Eso, eso :p https://t.co/jkX8ShUeic', 0.0, 'NEUTRO')
# ('Crema solar: ¿Cómo funciona su efecto protector? http://t.co/Rq9gVZV6h0 http://t.co/aoT1RihzRN', 0.0, 'NEUTRO')
# ('💬 Urbanización Atlanterra donde dice LaRazon que ha ido  .325€/semanales   {cheesy} https://t.co/qAF4GstPyq', -0.625, 'NEGATIVO')
# ('Descubren un fármaco que estimula la compasión http://t.co/GDnH6lnRFl http://t.co/bZh9Lj0sA1', -0.375, 'NEGATIVO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:40
# -------------------------------------------
# ('Recuerda que a las 16:00 horas puedes seguir la conferencia #xelFuturodeEspaña en Periscope y http://t.co/08eZ0fzjAi http://t.co/6kYWxun4SM', -0.25, 'NEGATIVO')
# ('"Con Montoro en Hacienda estamos ante el periodo más negro de la agencia tributaria" @pedrosaurag http://t.co/SZoIRy959e', -0.25, 'NEGATIVO')
# ('@Super_Estadio el unico que le puede dar un mejor stilo de juego,,sin duda el mejor hoy por hoy', 0.375, 'POSITIVO')
# ("El próximo 'Moto 360' podría venir en dos tamaños - http://t.co/NvZpzZGhzr http://t.co/f1aOFI5nJC", 0.0, 'NEUTRO')
# ('@Mezcalita_ Lo que quieras jugar en PC yo juego :D', 0.0, 'NEUTRO')
# ('Pedro Sánchez miente: 24.638 jóvenes han abandonado España según el INE, no 500.000 @marianorajoy #Sesióndecontrol', 0.625, 'POSITIVO')
# ('Pedro Miguel Echenique, #Premio #PríncipeDeAsturias, también en el #ICPEAC2015 (24/07) #Toledo http://t.co/8EvlZKI6oE http://t.co/tQt7Siqp9G', 0.0, 'NEUTRO')
# ('@ixhel_S @BigTimeParody GUAO!!! esta increíble :D GRACIAS! :*', 0.458, 'POSITIVO')
# ('Congratulations María!! :D https://t.co/bQmEjXsJQx', 0.0, 'NEUTRO')
# ('Que Buena Ondaa #FeriadoSimpson :D', 0.0, 'NEUTRO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:41
# -------------------------------------------
# ('@Prambors @narendrapawaka Calvin Harris aja :D', 0.0, 'NEUTRO')
# ('Tal cual :D http://t.co/HjrVZzRomT', 0.375, 'POSITIVO')
# ('Usando antibióticos para tratar la esquizofrenia http://t.co/cMwpRBwYdF http://t.co/vPjrPA3HnM', 0.0, 'NEUTRO')
# ('Sigue en directo la primera conferencia de Bethesda en el E3 - http://t.co/Y7hA1qIa0F http://t.co/xf9BazKAn2', 0.26, 'POSITIVO')
# ('Típico lo nuestro de siempre comer tarde los domingos :P', 0.375, 'POSITIVO')
# ('OJO! Samsung presenta un SSD de 16TB, el mayor almacenamiento del mundo http://t.co/LfCr17dcMD OMG! 16 terabytes :O http://t.co/AgzSJoyk3X', -0.375, 'NEGATIVO')
# ('Sí por favor, ponedme un juicio un lunes de Mayo en Toledo, que me sobra el tiempo', -1.0, 'NEGATIVO')
# ('¡Me encanta jugar #Apensar! Disponible en App Store http://t.co/y30gTL6xFx y en Google Play http://t.co/bm7CVvYKLQ http://t.co/Hh852XbQUN', 0.292, 'POSITIVO')
# ('Antonio Resines aboga por "cortar la conexión a Internet" a los piratas https://t.co/BqgGr1fLkT http://t.co/yoPnon2ba1', 0.0, 'NEUTRO')
# ('Me dan asco, pero están bonitos :P https://t.co/62eOZ4mflR', 0.0, 'NEUTRO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:42
# -------------------------------------------
# ('@Giancarlo_Tobar ahhh jajajajajajaja cierto...quien pensaría q a eso acudirían :P', 0.0, 'NEUTRO')
# ('Soy coder de ♡ no de ocasion :P', 0.375, 'POSITIVO')
# ('@LadonnaCostlow Hola :D aquí te comparto algo de música nueva http://t.co/GAv4Nwt4wB  Espero te agrade http://t.co/5nf0GrVP3C  Saludos^^', 0.0, 'NEUTRO')
# ('Andrea Levy rechaza que Rajoy tenga que acomodar su "calendario electoral" a Mas - Libertad Digital http://t.co/MnE6Lwxs6l', 0.469, 'POSITIVO')
# ('Me ha gustado un vídeo de @YouTube de @yakevin (http://t.co/onrYrXGaxW - Sobrevive al regreso a clases :D).', -0.375, 'NEGATIVO')
# ('¿Vienes a Talleres #CompletaDNos? ¿Nos vemos en #Alicante ?¿Sí? Pues Anímate y tuitea esta frase! Gracias :D https://t.co/cTPpcpBzYN', 0.0, 'NEUTRO')
# ('Una cover de Nirvana, por si acaso https://t.co/YjfrQDjy74', 0.0, 'NEUTRO')
# ('Precipita, la plataforma de financiación colectiva para ciencia de la Fecyt #Ciencia http://t.co/NJxfJ3KMxj http://t.co/bR7YTwC7DO', 0.0, 'NEUTRO')
# ('@LauroErica Gracias Erica, Me paso por la pagina :D', 0.0, 'NEUTRO')
# ('@FernandaPeralts https://t.co/kxWwWbwHhI este es mi canal seguro que te gusta,suscríbete por favor,muchas gracias :D', 0.375, 'POSITIVO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:43
# -------------------------------------------
# ('Clausura entrega diplomas Máster en Gobernanza @derecho_uam por Rebeca Grynspan, Scrta. Gnral. Iberoamericana http://t.co/BuPR2953NG', 0.25, 'POSITIVO')
# ('@mjpartera la noticia está actualizada, usted se refiere a la fecha de creación. Un saludo!', -0.375, 'NEGATIVO')
# ('"La educación es la preparación a la vida completa" (Spences) Muy buenos dias, #FelizMiercoles', 0.25, 'POSITIVO')
# ('20 cosas que NO deberías hacer antes de dormir http://t.co/GumtTEsXXL http://t.co/zNSMKpD81E', 0.375, 'POSITIVO')
# ('3. Si este es el juego, que conmigo no cuenten. Me da igual lo que pueda afectar a la promoción de MdT. No daré  información ni entrevistas.', 0.75, 'POSITIVO')
# ('Revelan fotos inéditas del desnudo más famoso de Marilyn Monroe https://t.co/LTFQsKbBwq http://t.co/mlxRtpl5VY', 1.0, 'POSITIVO')
# ('@microsiervos Hemos creado una web que explica el increíble viaje de @NewHorizons2015. Mola? .http://t.co/lNcp4G3uvh http://t.co/ze93AXne9C', 0.458, 'POSITIVO')
# ('@Torkolito el 31, pero tengo que registrar mi visa, mañana haré eso :p. Por cierto vendrás a ver a Tarja?', 0.0, 'NEUTRO')
# ('─¿Qué lenguaje de programación domina ud.?.─06:30■Informativos Telecinco.  08:55■El Programa de Ana Rosa .  12:45■MHYV....─Ya le llamaremos', 0.292, 'POSITIVO')
# ('Tengo tantos planes para hoy ... Buen Lunes ♥ :D', 0.734, 'POSITIVO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:44
# -------------------------------------------
# ('No eres gorda, eres fuerte! .Por lo menos cuando estas en movimiento acelerado (Fuerza = masa x aceleración)', 0.875, 'POSITIVO')
# ('@_PuroOjo Ay, no jodas! :p jajajajaja', 0.375, 'POSITIVO')
# ('@TioBraulio Gattaca sí que era buena', -0.25, 'NEGATIVO')
# ('Hoy cocino yo :D', 0.0, 'NEUTRO')
# ('Creo que voy a salir a conducir... solos... la carretera y yo... xD', 0.0, 'NEUTRO')
# ('Noticia: ReCore, el juego de Inafune y Armature Studio, podría llegar también a PC http://t.co/N9nbYkpZq1', 0.0, 'NEUTRO')
# ('@TheLastPingu ESTOY DE BUEN HUMOR :D', 0.734, 'POSITIVO')
# ('Graduación de los chicos y chicas de @fundacionprodis en @FaculEDUAM . Noticia @UAM_Biblioteca http://t.co/voQx1nr4ef', 0.0, 'NEUTRO')
# ('La #tecnología y el #juego como elementos claves de la #educación del #futuro http://t.co/Vs3SqABzjp vía AunCLICdelasTIC #TIC', 0.0, 'NEUTRO')
# ('La Noe es la mejor, me dice todo lo que tengo que hacer :D', 0.25, 'POSITIVO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:45
# -------------------------------------------
# ('@Val_Sierra14 jajaja see soy yo :p nooo como te paso eso?! Kite?', 0.0, 'NEUTRO')
# ('Oppo aprieta fuerte: está cerca de ser el próximo global partner del Barcelona http://t.co/EH4ZNaB3Og http://t.co/gGETcIIbBX', 0.347, 'POSITIVO')
# ('@GabyBenotti @santinunezpg1 vos no sabes nada querido jaja :p', 1.0, 'POSITIVO')
# ('Es muy triste que todos los libros de un ebook huelan igual.', -0.884, 'NEGATIVO')
# ('Logitech UE Roll, el altavoz que querrás en la ducha, la playa o la piscina http://t.co/cCkB4U7Ogo http://t.co/WWCQgnlEAM', 0.0, 'NEUTRO')
# ('@btsugus @btsvigan @tehyvngg y aja :(', 0.0, 'NEUTRO')
# ('Mujer, definición matemática :..Conjunto de curvas aerodinámicas que ofrecen la mayor resistencia y son capaces de poner recta una parábola.', 0.0, 'NEUTRO')
# ('Mañana, viernes 6M, Seminario Álgebra y Combinatoria en Fac. #Ciencias #UAM Organiza: @_ICMAT http://t.co/iYdShSNAhC http://t.co/qsN05667uH', 0.0, 'NEUTRO')
# ('@Rocioalmada00 igual yo :D', 0.0, 'NEUTRO')
# ('A partir de las 9:00, la vicesecretaria de Estudios y Programas @ALevySoler, es entrevistada en @La_SER http://t.co/gYCI6Me3IB', 0.375, 'POSITIVO')
# ...
#
# -------------------------------------------
# Time: 2020-01-12 21:28:46
# -------------------------------------------
# ('Especial: Los Minions invaden Android  http://t.co/K870z4tnrB http://t.co/AVnGOGA1BV', 0.0, 'NEUTRO')
# ('#ILookLikeAnEconomist y de las futuras más consultadas! :p http://t.co/nOpcdLFzVx', 0.0, 'NEUTRO')
# ('Finalizando mi primer día de clases un día trankilo :D', -0.375, 'NEGATIVO')
# ('Tenia que estas ya @Terafobia :D', 0.0, 'NEUTRO')
# ('@kellychrz9 4- porque eres la Cristina Yang de mi Meredith Grey, la puky de mi piky, esa amiga qque todas quisieran tener pero es MIA! :D', 0.375, 'POSITIVO')
# ('Will we ever understand the beginning of the universe? http://t.co/jdPCPY43Ig vía @aeonmag Heavy duty de cosmología. Necesario, no obstante.', 0.375, 'POSITIVO')
# ('En #Lleida todo preparado para la envestidura de @angelrosdomingo como paer en cap @lleidapsc #ColorPSOE http://t.co/J1vzZSGJT6', 0.781, 'POSITIVO')
# ('@pilsua la mitad que la Liga MX :P', 0.0, 'NEUTRO')
# ('¿Por qué los tatuajes son permanentes? http://t.co/TwoaYa5ctA http://t.co/zM8fqJ3Rlc', 0.0, 'NEUTRO')
# ('Acer Chromebook 15 es el Chromebook más grande hasta la fecha - http://t.co/w9NLk7tk5z http://t.co/zYHk24Te8a', 0.292, 'POSITIVO')
# ...
