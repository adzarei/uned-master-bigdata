# %% [markdown]
# # Ejercicio 2 (hashtags más utilizados): (2 puntos)
# Desarrollar un notebook de Jupyter, denominado “hashtags.ipynb”, en el que se utilice como fuente de datos Kafka, y en concreto el topic kafkaTwitter. La duración del batch será de 5 segundos. Se procesarán los tweets que lleguen para extraer los hashtags que contengan (tener en cuenta que todos los hashtags comienzan por el carácter ‘#’).
#
# Se irán mostrando, cada vez que se procese el batch (5 segundos) <b> los diez hashtags más utilizados desde el inicio del programa hasta ese momento y el número total de apariciones de cada uno, ordenados de mayor a menor frecuencia.</b>

# %%
import findspark
findspark.init('/opt/spark')

# %%
import os
os.environ['JAVA_HOME'] = '/Library/Java/JavaVirtualMachines/jdk1.8.0_171.jdk/Contents/Home/jre'
os.environ['PYSPARK_SUBMIT_ARGS'] = '--master local[*] --packages org.apache.spark:spark-streaming-kafka-0-8_2.11:2.4.4 pyspark-shell'

# %%
import pyspark
import pyspark.streaming
from pyspark import SparkConf, SparkContext
from pyspark.sql import SparkSession
from pyspark.streaming import StreamingContext
from pyspark.streaming.kafka import KafkaUtils

# %%
#sc = SparkContext(master="local[*]", appName="Tweet Count")
spark = SparkSession.builder.appName("hashtags").master("local[*]").getOrCreate()

# 5s de batchDuration
ssc = StreamingContext(spark.sparkContext, 5)

ssc.checkpoint("checkpoint")

# %%
# DStream con el batch de 5s de Kafka.
kafkaStream = KafkaUtils.createStream(ssc,zkQuorum='localhost:2181',groupId="group_1" , topics={'kafkaTwitter':2})

# %%
words = kafkaStream.flatMap(lambda message: (message[1].split(" ")))
# Nos quedamos con las palabras que contienen # porque algunos elementos no tienen un espacio antes del #.
# ej. :D.#MTVHottest,
hastags = words.filter(lambda word: ("#" in word))

# %%
import re

def getRegex(word, regex):
    match_obj = re.search(regex, word)
    
    if type(match_obj) is None:
        return "NULL"
    else :
        return match_obj.group()

# %%
# Filtramos con una expresión regular para quedarnos con el # y la palabra que lo acompaña.
clean_hastags = hastags.map(lambda x: (getRegex(x,'#\w+')))

# %%
# Mapeamos cada hastag como key y 1 como value para contarlos.
local_hastag_count = clean_hastags.map( lambda ht: (ht, 1))

# %%
# Función para actualizar el conteo global con la suma del conteo local del batch en ejecución.
def updateFunction(newValues, localCount):
    return sum(newValues) + (localCount or 0)

# %%
global_hastag_count = local_hastag_count.updateStateByKey(updateFunc=updateFunction)

# %%
# Ordenamos por value en orden descendiente.
result = global_hastag_count.transform( lambda ht_count: (ht_count.sortBy(lambda pair: ( pair[1]), ascending=False)))

# %%
# Mostramos los primero 10 valores -> los 10 valores mas altos.
result.pprint(10)

# %%
ssc.start()
# Out:
# -------------------------------------------
# Time: 2020-01-11 20:51:40
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-01-11 20:51:45
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-01-11 20:51:50
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-01-11 20:51:55
# -------------------------------------------
#
# -------------------------------------------
# Time: 2020-01-11 20:52:00
# -------------------------------------------
# ('#UAM', 1)
# ('#EmPPleo', 1)
# ('#YoTambiénAmoALosAnimales', 1)
# ('#Actualizaciones', 1)
# ('#hot', 1)
# ('#SID2014', 1)
# ('#CospedalAsturias', 1)
# ('#FelizMiércoles', 1)
# ('#ElCambioQueUne', 1)
# ('#Apple', 1)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:05
# -------------------------------------------
# ('#UAM', 2)
# ('#InvertirEnPersonas', 2)
# ('#EmPPleo', 1)
# ('#YoTambiénAmoALosAnimales', 1)
# ('#Actualizaciones', 1)
# ('#hot', 1)
# ('#SID2014', 1)
# ('#CospedalAsturias', 1)
# ('#frikismo', 1)
# ('#FelizViernes', 1)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:10
# -------------------------------------------
# ('#UAM', 3)
# ('#InvertirEnPersonas', 2)
# ('#EmPPleo', 1)
# ('#YoTambiénAmoALosAnimales', 1)
# ('#Actualizaciones', 1)
# ('#hot', 1)
# ('#ordenadores', 1)
# ('#másteres', 1)
# ('#videojuegos', 1)
# ('#Donasangre', 1)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:15
# -------------------------------------------
# ('#UAM', 3)
# ('#PGE2016', 3)
# ('#APOCALIPSISMINECRAFT4', 2)
# ('#ForoCambio11J', 2)
# ('#InvertirEnPersonas', 2)
# ('#TuitUtil', 2)
# ('#UniDeVerano', 2)
# ('#EmPPleo', 1)
# ('#YoTambiénAmoALosAnimales', 1)
# ('#Actualizaciones', 1)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:20
# -------------------------------------------
# ('#UAM', 3)
# ('#PGE2016', 3)
# ('#RutaDelCambio', 3)
# ('#APOCALIPSISMINECRAFT4', 2)
# ('#Apensar', 2)
# ('#ForoCambio11J', 2)
# ('#InvertirEnPersonas', 2)
# ('#TuitUtil', 2)
# ('#PresidentaCospedal', 2)
# ('#UniDeVerano', 2)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:25
# -------------------------------------------
# ('#UAM', 4)
# ('#ForoCambio11J', 4)
# ('#RdPPodemos', 3)
# ('#Apple', 3)
# ('#PGE2016', 3)
# ('#UniDeVerano', 3)
# ('#RutaDelCambio', 3)
# ('#APOCALIPSISMINECRAFT4', 2)
# ('#Apensar', 2)
# ('#PSOE24M', 2)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:30
# -------------------------------------------
# ('#ForoCambio11J', 5)
# ('#UAM', 4)
# ('#Apple', 4)
# ('#RdPPodemos', 3)
# ('#PGE2016', 3)
# ('#UniDeVerano', 3)
# ('#RutaDelCambio', 3)
# ('#APOCALIPSISMINECRAFT4', 2)
# ('#Apensar', 2)
# ('#PSOE24M', 2)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:35
# -------------------------------------------
# ('#UAM', 6)
# ('#ForoCambio11J', 5)
# ('#Apple', 4)
# ('#UniDeVerano', 4)
# ('#RdPPodemos', 3)
# ('#PGE2016', 3)
# ('#digoSIvotoPSOE', 3)
# ('#RutaDelCambio', 3)
# ('#APOCALIPSISMINECRAFT4', 2)
# ('#FelizViernes', 2)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:40
# -------------------------------------------
# ('#ForoCambio11J', 7)
# ('#UAM', 6)
# ('#Apple', 5)
# ('#UniDeVerano', 4)
# ('#RdPPodemos', 3)
# ('#PSOE24M', 3)
# ('#PGE2016', 3)
# ('#digoSIvotoPSOE', 3)
# ('#RutaDelCambio', 3)
# ('#APOCALIPSISMINECRAFT4', 2)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:45
# -------------------------------------------
# ('#UAM', 8)
# ('#ForoCambio11J', 8)
# ('#Apple', 6)
# ('#TuitUtil', 4)
# ('#UniDeVerano', 4)
# ('#RdPPodemos', 3)
# ('#PSOE24M', 3)
# ('#PGE2016', 3)
# ('#digoSIvotoPSOE', 3)
# ('#RutaDelCambio', 3)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:50
# -------------------------------------------
# ('#UAM', 9)
# ('#ForoCambio11J', 9)
# ('#Apple', 6)
# ('#PGE2016', 5)
# ('#TuitUtil', 4)
# ('#UniDeVerano', 4)
# ('#RdPPodemos', 3)
# ('#PSOE24M', 3)
# ('#digoSIvotoPSOE', 3)
# ('#MTVHottest', 3)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:52:55
# -------------------------------------------
# ('#UAM', 10)
# ('#ForoCambio11J', 9)
# ('#Apple', 6)
# ('#PGE2016', 5)
# ('#UniDeVerano', 5)
# ('#TuitUtil', 4)
# ('#RdPPodemos', 3)
# ('#Apensar', 3)
# ('#PSOE24M', 3)
# ('#digoSIvotoPSOE', 3)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:53:00
# -------------------------------------------
# ('#UAM', 11)
# ('#ForoCambio11J', 10)
# ('#Apple', 7)
# ('#PGE2016', 5)
# ('#UniDeVerano', 5)
# ('#RdPPodemos', 4)
# ('#digoSIvotoPSOE', 4)
# ('#TuitUtil', 4)
# ('#Ciencia', 4)
# ('#APOCALIPSISMINECRAFT4', 3)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:53:05
# -------------------------------------------
# ('#UAM', 12)
# ('#ForoCambio11J', 11)
# ('#Apple', 7)
# ('#RdPPodemos', 5)
# ('#PGE2016', 5)
# ('#UniDeVerano', 5)
# ('#FelizMiercoles', 4)
# ('#digoSIvotoPSOE', 4)
# ('#TuitUtil', 4)
# ('#Ciencia', 4)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:53:10
# -------------------------------------------
# ('#UAM', 13)
# ('#ForoCambio11J', 11)
# ('#Apple', 7)
# ('#RdPPodemos', 5)
# ('#PGE2016', 5)
# ('#FelizMiercoles', 5)
# ('#UniDeVerano', 5)
# ('#TrabajarHacerCrecer', 5)
# ('#digoSIvotoPSOE', 4)
# ('#TuitUtil', 4)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:53:15
# -------------------------------------------
# ('#UAM', 13)
# ('#ForoCambio11J', 12)
# ('#Apple', 7)
# ('#PGE2016', 6)
# ('#FelizMiercoles', 6)
# ('#RdPPodemos', 5)
# ('#digoSIvotoPSOE', 5)
# ('#UniDeVerano', 5)
# ('#TrabajarHacerCrecer', 5)
# ('#PSOE24M', 4)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:53:20
# -------------------------------------------
# ('#UAM', 16)
# ('#ForoCambio11J', 12)
# ('#Apple', 9)
# ('#PGE2016', 6)
# ('#FelizMiercoles', 6)
# ('#RdPPodemos', 5)
# ('#digoSIvotoPSOE', 5)
# ('#UniDeVerano', 5)
# ('#TrabajarHacerCrecer', 5)
# ('#Ciencia', 5)
# ...
#
# -------------------------------------------
# Time: 2020-01-11 20:53:25
# -------------------------------------------
# ('#UAM', 17)
# ('#ForoCambio11J', 12)
# ('#Apple', 9)
# ('#PGE2016', 6)
# ('#FelizMiercoles', 6)
# ('#Ciencia', 6)
# ('#RdPPodemos', 5)
# ('#PSOE24M', 5)
# ('#digoSIvotoPSOE', 5)
# ('#UniDeVerano', 5)
# ...
