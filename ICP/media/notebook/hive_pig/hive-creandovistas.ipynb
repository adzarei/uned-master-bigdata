# %% [markdown]
# ## Creando vistas

# %%
! mkdir -p hive-vistas
import os
os.chdir("hive-vistas")

# %%
! pwd
# Out:
# /home/cloudera/HadoopNotebooks/Hive/hive-vistas/hive-vistas

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "create view viewdatacleaninternalparticionB as select gsm19023, gsd19024 from datacleaninternalparticion;"
# Out:
# scan complete in 2ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112015151_05a8a9fc-cd40-4cd9-b4b1-b09304e9afa5): create view viewdatacleaninternalparticionB as select gsm19023, gsd19024 from datacleaninternalparticion
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:gsm19023, type:float, comment:null), FieldSchema(name:gsd19024, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112015151_05a8a9fc-cd40-4cd9-b4b1-b09304e9afa5); Time taken: 0.083 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# ...

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "create view viewdatacleaninternalbucketB as select gsm19023, gsd19024 from datacleaninternalbucket;"
# Out:
# scan complete in 2ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112015151_ac80f748-830b-4b15-a005-d15f61ba9ec9): create view viewdatacleaninternalbucketB as select gsm19023, gsd19024 from datacleaninternalbucket
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:gsm19023, type:float, comment:null), FieldSchema(name:gsd19024, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112015151_ac80f748-830b-4b15-a005-d15f61ba9ec9); Time taken: 0.082 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# ...

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "create view viewdatacleaninternalB as select gsm19023, gsd19024 from datacleaninternal;"
# Out:
# scan complete in 2ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112020101_4bab9b32-952d-4663-b547-309a56f7fe16): create view viewdatacleaninternalB as select gsm19023, gsd19024 from datacleaninternal
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:gsm19023, type:float, comment:null), FieldSchema(name:gsd19024, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112020101_4bab9b32-952d-4663-b547-309a56f7fe16); Time taken: 0.088 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# ...

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "create view viewdatacleanexternalparticionB as select gsm19023, gsd19024 from datacleanexternalparticion;"
# Out:
# scan complete in 2ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112020101_f0a1352f-a2b2-41f5-a54b-57fe91be6385): create view viewdatacleanexternalparticionB as select gsm19023, gsd19024 from datacleanexternalparticion
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:gsm19023, type:float, comment:null), FieldSchema(name:gsd19024, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112020101_f0a1352f-a2b2-41f5-a54b-57fe91be6385); Time taken: 0.091 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# ...

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "create view viewdatacleanexternalbucketB as select gsm19023, gsd19024 from datacleanexternalbucketB;"
# Out:
# scan complete in 1ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112020101_092f86cc-a379-4456-b371-58d57e62e73a): create view viewdatacleanexternalbucketB as select gsm19023, gsd19024 from datacleanexternalbucketB
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:gsm19023, type:float, comment:null), FieldSchema(name:gsd19024, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112020101_092f86cc-a379-4456-b371-58d57e62e73a); Time taken: 0.07 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# ...

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "create view viewdatacleanexternalB as select gsm19023, gsd19024 from datacleanexternalB;"
# Out:
# scan complete in 2ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112020303_b045fa5d-ad29-4661-bb61-4b947213d2b4): create view viewdatacleanexternalB as select gsm19023, gsd19024 from datacleanexternalB
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:gsm19023, type:float, comment:null), FieldSchema(name:gsd19024, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112020303_b045fa5d-ad29-4661-bb61-4b947213d2b4); Time taken: 0.081 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# ...

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "show tables;"
# Out:
# scan complete in 2ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112020202_91c68406-c78b-492e-945c-e927582ed0fb): show tables
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:tab_name, type:string, comment:from deserializer)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112020202_91c68406-c78b-492e-945c-e927582ed0fb); Time taken: 0.048 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20180112020202_91c68406-c78b-492e-945c-e927582ed0fb): show tables
# INFO  : Starting task [Stage-0:DDL] in serial mode
# ...

# %%
! beeline -u "jdbc:hive2://localhost:10000/bioinformatica" -e "select * from viewdatacleanexternalB;"
# Out:
# scan complete in 1ms
# Connecting to jdbc:hive2://localhost:10000/bioinformatica
# Connected to: Apache Hive (version 1.1.0-cdh5.12.0)
# Driver: Hive JDBC (version 1.1.0-cdh5.12.0)
# Transaction isolation: TRANSACTION_REPEATABLE_READ
# INFO  : Compiling command(queryId=hive_20180112020303_f1aa8073-3034-4d22-8215-4deb01bad5f8): select * from viewdatacleanexternalB
# INFO  : Semantic Analysis Completed
# INFO  : Returning Hive schema: Schema(fieldSchemas:[FieldSchema(name:viewdatacleanexternalb.gsm19023, type:float, comment:null), FieldSchema(name:viewdatacleanexternalb.gsd19024, type:float, comment:null)], properties:null)
# INFO  : Completed compiling command(queryId=hive_20180112020303_f1aa8073-3034-4d22-8215-4deb01bad5f8); Time taken: 0.097 seconds
# INFO  : Concurrency mode is disabled, not creating a lock manager
# INFO  : Executing command(queryId=hive_20180112020303_f1aa8073-3034-4d22-8215-4deb01bad5f8): select * from viewdatacleanexternalB
# ...
